# %%
# Import Dependencies
import pandas as pd
from datetime import timedelta, date
import numpy as np
import matplotlib.pyplot as plt
import requests as requests

# %%
#CDC COVID-19 vaccination in the US url
vax_url = "https://data.cdc.gov/resource/8xkx-amqh"

# %%
#request API and get json objects

vax_response = requests.get(vax_url).json()
vax_response
# Out:
# [{'date': '2021-10-20T00:00:00.000',
#   'fips': '28161',
#   'mmwr_week': '42',
#   'recip_county': 'Yalobusha County',
#   'recip_state': 'MS',
#   'series_complete_pop_pct': '59.1',
#   'series_complete_yes': '7154',
#   'series_complete_12plus': '7153',
#   'series_complete_12pluspop': '68.9',
#   'series_complete_18plus': '6850',
#   'series_complete_18pluspop': '72.6',
#   'series_complete_65plus': '2501',
#   'series_complete_65pluspop': '98.3',
#   'completeness_pct': '98.3',
#   'administered_dose1_recip': '8034',
#   'administered_dose1_pop_pct': '66.4',
#   'administered_dose1_recip_12plus': '8033',
#   'administered_dose1_recip_12pluspop_pct': '77.4',
#   'administered_dose1_recip_18plus': '7657',
#   'administered_dose1_recip_18pluspop_pct': '81.1',
#   'administered_dose1_recip_65plus': '2661',
#   'administered_dose1_recip_65pluspop_pct': '99.9',
#   'svi_ctgy': 'C',
#   'series_complete_pop_pct_svi': '12',
#   'series_complete_12pluspop_pct_svi': '12',
#   'series_complete_18pluspop_pct_svi': '12',
#   'series_complete_65pluspop_pct_svi': '12',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '8',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '13229',
#   'mmwr_week': '42',
#   'recip_county': 'Pierce County',
#   'recip_state': 'GA',
#   'series_complete_pop_pct': '24.4',
#   'series_complete_yes': '4748',
#   'series_complete_12plus': '4748',
#   'series_complete_12pluspop': '29.0',
#   'series_complete_18plus': '4587',
#   'series_complete_18pluspop': '31.2',
#   'series_complete_65plus': '1742',
#   'series_complete_65pluspop': '51.3',
#   'completeness_pct': '57.6',
#   'administered_dose1_recip': '5518',
#   'administered_dose1_pop_pct': '28.3',
#   'administered_dose1_recip_12plus': '5518',
#   'administered_dose1_recip_12pluspop_pct': '33.7',
#   'administered_dose1_recip_18plus': '5312',
#   'administered_dose1_recip_18pluspop_pct': '36.1',
#   'administered_dose1_recip_65plus': '1916',
#   'administered_dose1_recip_65pluspop_pct': '56.4',
#   'svi_ctgy': 'C',
#   'series_complete_pop_pct_svi': '9',
#   'series_complete_12pluspop_pct_svi': '9',
#   'series_complete_18pluspop_pct_svi': '10',
#   'series_complete_65pluspop_pct_svi': '11',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '5',
#   'series_complete_12pluspop_pct_ur_equity': '5',
#   'series_complete_18pluspop_pct_ur_equity': '6',
#   'series_complete_65pluspop_pct_ur_equity': '7'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '27169',
#   'mmwr_week': '42',
#   'recip_county': 'Winona County',
#   'recip_state': 'MN',
#   'series_complete_pop_pct': '53.2',
#   'series_complete_yes': '26839',
#   'series_complete_12plus': '26776',
#   'series_complete_12pluspop': '59.9',
#   'series_complete_18plus': '25094',
#   'series_complete_18pluspop': '60.4',
#   'series_complete_65plus': '7943',
#   'series_complete_65pluspop': '89.3',
#   'completeness_pct': '94',
#   'administered_dose1_recip': '29743',
#   'administered_dose1_pop_pct': '58.9',
#   'administered_dose1_recip_12plus': '29663',
#   'administered_dose1_recip_12pluspop_pct': '66.4',
#   'administered_dose1_recip_18plus': '27899',
#   'administered_dose1_recip_18pluspop_pct': '67.2',
#   'administered_dose1_recip_65plus': '8820',
#   'administered_dose1_recip_65pluspop_pct': '99.1',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '4',
#   'series_complete_12pluspop_pct_svi': '4',
#   'series_complete_18pluspop_pct_svi': '4',
#   'series_complete_65pluspop_pct_svi': '4',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '8',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '19083',
#   'mmwr_week': '42',
#   'recip_county': 'Hardin County',
#   'recip_state': 'IA',
#   'series_complete_pop_pct': '50.5',
#   'series_complete_yes': '8510',
#   'series_complete_12plus': '8510',
#   'series_complete_12pluspop': '57.6',
#   'series_complete_18plus': '8196',
#   'series_complete_18pluspop': '60.5',
#   'series_complete_65plus': '3258',
#   'series_complete_65pluspop': '85.7',
#   'completeness_pct': '97.5',
#   'administered_dose1_recip': '8937',
#   'administered_dose1_pop_pct': '53.1',
#   'administered_dose1_recip_12plus': '8937',
#   'administered_dose1_recip_12pluspop_pct': '60.5',
#   'administered_dose1_recip_18plus': '8555',
#   'administered_dose1_recip_18pluspop_pct': '63.1',
#   'administered_dose1_recip_65plus': '3297',
#   'administered_dose1_recip_65pluspop_pct': '86.7',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '4',
#   'series_complete_12pluspop_pct_svi': '4',
#   'series_complete_18pluspop_pct_svi': '4',
#   'series_complete_65pluspop_pct_svi': '4',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '8',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '55027',
#   'mmwr_week': '42',
#   'recip_county': 'Dodge County',
#   'recip_state': 'WI',
#   'series_complete_pop_pct': '46.3',
#   'series_complete_yes': '40685',
#   'series_complete_12plus': '40685',
#   'series_complete_12pluspop': '52.7',
#   'series_complete_18plus': '38675',
#   'series_complete_18pluspop': '54.7',
#   'series_complete_65plus': '13395',
#   'series_complete_65pluspop': '83.7',
#   'completeness_pct': '97',
#   'administered_dose1_recip': '43365',
#   'administered_dose1_pop_pct': '49.4',
#   'administered_dose1_recip_12plus': '43364',
#   'administered_dose1_recip_12pluspop_pct': '56.2',
#   'administered_dose1_recip_18plus': '41046',
#   'administered_dose1_recip_18pluspop_pct': '58.1',
#   'administered_dose1_recip_65plus': '13825',
#   'administered_dose1_recip_65pluspop_pct': '86.4',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '3',
#   'series_complete_12pluspop_pct_svi': '4',
#   'series_complete_18pluspop_pct_svi': '4',
#   'series_complete_65pluspop_pct_svi': '4',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '46023',
#   'mmwr_week': '42',
#   'recip_county': 'Charles Mix County',
#   'recip_state': 'SD',
#   'series_complete_pop_pct': '42.6',
#   'series_complete_yes': '3960',
#   'series_complete_12plus': '3959',
#   'series_complete_12pluspop': '53.8',
#   'series_complete_18plus': '3687',
#   'series_complete_18pluspop': '56.5',
#   'series_complete_65plus': '1251',
#   'series_complete_65pluspop': '72.4',
#   'completeness_pct': '85',
#   'administered_dose1_recip': '4837',
#   'administered_dose1_pop_pct': '52.1',
#   'administered_dose1_recip_12pluspop_pct': '0.0',
#   'administered_dose1_recip_18pluspop_pct': '0',
#   'administered_dose1_recip_65pluspop_pct': '0',
#   'svi_ctgy': 'C',
#   'series_complete_pop_pct_svi': '11',
#   'series_complete_12pluspop_pct_svi': '12',
#   'series_complete_18pluspop_pct_svi': '12',
#   'series_complete_65pluspop_pct_svi': '12',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '21121',
#   'mmwr_week': '42',
#   'recip_county': 'Knox County',
#   'recip_state': 'KY',
#   'series_complete_pop_pct': '32.4',
#   'series_complete_yes': '10098',
#   'series_complete_12plus': '10098',
#   'series_complete_12pluspop': '38.2',
#   'series_complete_18plus': '9727',
#   'series_complete_18pluspop': '40.6',
#   'series_complete_65plus': '3179',
#   'series_complete_65pluspop': '57.6',
#   'completeness_pct': '94.4',
#   'administered_dose1_recip': '11293',
#   'administered_dose1_pop_pct': '36.3',
#   'administered_dose1_recip_12plus': '11293',
#   'administered_dose1_recip_12pluspop_pct': '42.7',
#   'administered_dose1_recip_18plus': '10854',
#   'administered_dose1_recip_18pluspop_pct': '45.3',
#   'administered_dose1_recip_65plus': '3326',
#   'administered_dose1_recip_65pluspop_pct': '60.2',
#   'svi_ctgy': 'D',
#   'series_complete_pop_pct_svi': '14',
#   'series_complete_12pluspop_pct_svi': '14',
#   'series_complete_18pluspop_pct_svi': '15',
#   'series_complete_65pluspop_pct_svi': '15',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '6',
#   'series_complete_12pluspop_pct_ur_equity': '6',
#   'series_complete_18pluspop_pct_ur_equity': '7',
#   'series_complete_65pluspop_pct_ur_equity': '7'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '24033',
#   'mmwr_week': '42',
#   'recip_county': "Prince George's County",
#   'recip_state': 'MD',
#   'series_complete_pop_pct': '62.5',
#   'series_complete_yes': '568539',
#   'series_complete_12plus': '568497',
#   'series_complete_12pluspop': '73.7',
#   'series_complete_18plus': '525692',
#   'series_complete_18pluspop': '74.2',
#   'series_complete_65plus': '108901',
#   'series_complete_65pluspop': '86.2',
#   'completeness_pct': '98.7',
#   'administered_dose1_recip': '645893',
#   'administered_dose1_pop_pct': '71',
#   'administered_dose1_recip_12plus': '645762',
#   'administered_dose1_recip_12pluspop_pct': '83.7',
#   'administered_dose1_recip_18plus': '594198',
#   'administered_dose1_recip_18pluspop_pct': '83.9',
#   'administered_dose1_recip_65plus': '118349',
#   'administered_dose1_recip_65pluspop_pct': '93.7',
#   'svi_ctgy': 'C',
#   'series_complete_pop_pct_svi': '12',
#   'series_complete_12pluspop_pct_svi': '12',
#   'series_complete_18pluspop_pct_svi': '12',
#   'series_complete_65pluspop_pct_svi': '12',
#   'metro_status': 'Metro',
#   'series_complete_pop_pct_ur_equity': '4',
#   'series_complete_12pluspop_pct_ur_equity': '4',
#   'series_complete_18pluspop_pct_ur_equity': '4',
#   'series_complete_65pluspop_pct_ur_equity': '4'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '01121',
#   'mmwr_week': '42',
#   'recip_county': 'Talladega County',
#   'recip_state': 'AL',
#   'series_complete_pop_pct': '32.4',
#   'series_complete_yes': '25913',
#   'series_complete_12plus': '25913',
#   'series_complete_12pluspop': '37.4',
#   'series_complete_18plus': '24868',
#   'series_complete_18pluspop': '39.3',
#   'series_complete_65plus': '9001',
#   'series_complete_65pluspop': '60.9',
#   'completeness_pct': '92.5',
#   'administered_dose1_recip': '31755',
#   'administered_dose1_pop_pct': '39.7',
#   'administered_dose1_recip_12plus': '31754',
#   'administered_dose1_recip_12pluspop_pct': '45.8',
#   'administered_dose1_recip_18plus': '30360',
#   'administered_dose1_recip_18pluspop_pct': '48',
#   'administered_dose1_recip_65plus': '10298',
#   'administered_dose1_recip_65pluspop_pct': '69.7',
#   'svi_ctgy': 'D',
#   'series_complete_pop_pct_svi': '14',
#   'series_complete_12pluspop_pct_svi': '14',
#   'series_complete_18pluspop_pct_svi': '14',
#   'series_complete_65pluspop_pct_svi': '15',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '6',
#   'series_complete_12pluspop_pct_ur_equity': '6',
#   'series_complete_18pluspop_pct_ur_equity': '6',
#   'series_complete_65pluspop_pct_ur_equity': '7'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '19067',
#   'mmwr_week': '42',
#   'recip_county': 'Floyd County',
#   'recip_state': 'IA',
#   'series_complete_pop_pct': '48.4',
#   'series_complete_yes': '7569',
#   'series_complete_12plus': '7569',
#   'series_complete_12pluspop': '56.8',
#   'series_complete_18plus': '7211',
#   'series_complete_18pluspop': '59.7',
#   'series_complete_65plus': '2780',
#   'series_complete_65pluspop': '79.9',
#   'completeness_pct': '97.5',
#   'administered_dose1_recip': '7941',
#   'administered_dose1_pop_pct': '50.8',
#   'administered_dose1_recip_12plus': '7941',
#   'administered_dose1_recip_12pluspop_pct': '59.6',
#   'administered_dose1_recip_18plus': '7539',
#   'administered_dose1_recip_18pluspop_pct': '62.4',
#   'administered_dose1_recip_65plus': '2866',
#   'administered_dose1_recip_65pluspop_pct': '82.4',
#   'svi_ctgy': 'B',
#   'series_complete_pop_pct_svi': '7',
#   'series_complete_12pluspop_pct_svi': '8',
#   'series_complete_18pluspop_pct_svi': '8',
#   'series_complete_65pluspop_pct_svi': '8',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '13211',
#   'mmwr_week': '42',
#   'recip_county': 'Morgan County',
#   'recip_state': 'GA',
#   'series_complete_pop_pct': '22.8',
#   'series_complete_yes': '4403',
#   'series_complete_12plus': '4403',
#   'series_complete_12pluspop': '26.6',
#   'series_complete_18plus': '4124',
#   'series_complete_18pluspop': '27.6',
#   'series_complete_65plus': '1635',
#   'series_complete_65pluspop': '41.5',
#   'completeness_pct': '57.6',
#   'administered_dose1_recip': '4674',
#   'administered_dose1_pop_pct': '24.2',
#   'administered_dose1_recip_12plus': '4674',
#   'administered_dose1_recip_12pluspop_pct': '28.3',
#   'administered_dose1_recip_18plus': '4331',
#   'administered_dose1_recip_18pluspop_pct': '29',
#   'administered_dose1_recip_65plus': '1695',
#   'administered_dose1_recip_65pluspop_pct': '43',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '1',
#   'series_complete_12pluspop_pct_svi': '1',
#   'series_complete_18pluspop_pct_svi': '1',
#   'series_complete_65pluspop_pct_svi': '2',
#   'metro_status': 'Metro',
#   'series_complete_pop_pct_ur_equity': '1',
#   'series_complete_12pluspop_pct_ur_equity': '1',
#   'series_complete_18pluspop_pct_ur_equity': '1',
#   'series_complete_65pluspop_pct_ur_equity': '2'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '54093',
#   'mmwr_week': '42',
#   'recip_county': 'Tucker County',
#   'recip_state': 'WV',
#   'series_complete_pop_pct': '30.4',
#   'series_complete_yes': '2082',
#   'series_complete_12plus': '2082',
#   'series_complete_12pluspop': '33.6',
#   'series_complete_18plus': '1975',
#   'series_complete_18pluspop': '33.9',
#   'series_complete_65plus': '811',
#   'series_complete_65pluspop': '44.2',
#   'completeness_pct': '59.9',
#   'administered_dose1_recip': '2380',
#   'administered_dose1_pop_pct': '34.8',
#   'administered_dose1_recip_12plus': '2380',
#   'administered_dose1_recip_12pluspop_pct': '38.4',
#   'administered_dose1_recip_18plus': '2248',
#   'administered_dose1_recip_18pluspop_pct': '38.6',
#   'administered_dose1_recip_65plus': '894',
#   'administered_dose1_recip_65pluspop_pct': '48.7',
#   'svi_ctgy': 'B',
#   'series_complete_pop_pct_svi': '6',
#   'series_complete_12pluspop_pct_svi': '6',
#   'series_complete_18pluspop_pct_svi': '6',
#   'series_complete_65pluspop_pct_svi': '6',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '6',
#   'series_complete_12pluspop_pct_ur_equity': '6',
#   'series_complete_18pluspop_pct_ur_equity': '6',
#   'series_complete_65pluspop_pct_ur_equity': '6'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '05139',
#   'mmwr_week': '42',
#   'recip_county': 'Union County',
#   'recip_state': 'AR',
#   'series_complete_pop_pct': '41.9',
#   'series_complete_yes': '16211',
#   'series_complete_12plus': '16205',
#   'series_complete_12pluspop': '49.8',
#   'series_complete_18plus': '15300',
#   'series_complete_18pluspop': '52',
#   'series_complete_65plus': '5053',
#   'series_complete_65pluspop': '71',
#   'completeness_pct': '90.2',
#   'administered_dose1_recip': '20279',
#   'administered_dose1_pop_pct': '52.4',
#   'administered_dose1_recip_12plus': '20258',
#   'administered_dose1_recip_12pluspop_pct': '62.2',
#   'administered_dose1_recip_18plus': '18895',
#   'administered_dose1_recip_18pluspop_pct': '64.2',
#   'administered_dose1_recip_65plus': '5996',
#   'administered_dose1_recip_65pluspop_pct': '84.2',
#   'svi_ctgy': 'D',
#   'series_complete_pop_pct_svi': '15',
#   'series_complete_12pluspop_pct_svi': '15',
#   'series_complete_18pluspop_pct_svi': '16',
#   'series_complete_65pluspop_pct_svi': '16',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '7',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '04019',
#   'mmwr_week': '42',
#   'recip_county': 'Pima County',
#   'recip_state': 'AZ',
#   'series_complete_pop_pct': '58.9',
#   'series_complete_yes': '616936',
#   'series_complete_12plus': '616709',
#   'series_complete_12pluspop': '68.1',
#   'series_complete_18plus': '577605',
#   'series_complete_18pluspop': '69.4',
#   'series_complete_65plus': '186157',
#   'series_complete_65pluspop': '87.6',
#   'completeness_pct': '97.6',
#   'administered_dose1_recip': '702461',
#   'administered_dose1_pop_pct': '67.1',
#   'administered_dose1_recip_12plus': '702092',
#   'administered_dose1_recip_12pluspop_pct': '77.5',
#   'administered_dose1_recip_18plus': '654779',
#   'administered_dose1_recip_18pluspop_pct': '78.7',
#   'administered_dose1_recip_65plus': '205505',
#   'administered_dose1_recip_65pluspop_pct': '96.7',
#   'svi_ctgy': 'D',
#   'series_complete_pop_pct_svi': '16',
#   'series_complete_12pluspop_pct_svi': '16',
#   'series_complete_18pluspop_pct_svi': '16',
#   'series_complete_65pluspop_pct_svi': '16',
#   'metro_status': 'Metro',
#   'series_complete_pop_pct_ur_equity': '4',
#   'series_complete_12pluspop_pct_ur_equity': '4',
#   'series_complete_18pluspop_pct_ur_equity': '4',
#   'series_complete_65pluspop_pct_ur_equity': '4'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '30061',
#   'mmwr_week': '42',
#   'recip_county': 'Mineral County',
#   'recip_state': 'MT',
#   'series_complete_pop_pct': '48.4',
#   'series_complete_yes': '2127',
#   'series_complete_12plus': '2127',
#   'series_complete_12pluspop': '54.7',
#   'series_complete_18plus': '2042',
#   'series_complete_18pluspop': '56.8',
#   'series_complete_65plus': '947',
#   'series_complete_65pluspop': '72.8',
#   'completeness_pct': '95.7',
#   'administered_dose1_recip': '2413',
#   'administered_dose1_pop_pct': '54.9',
#   'administered_dose1_recip_12plus': '2411',
#   'administered_dose1_recip_12pluspop_pct': '62.0',
#   'administered_dose1_recip_18plus': '2307',
#   'administered_dose1_recip_18pluspop_pct': '64.1',
#   'administered_dose1_recip_65plus': '1042',
#   'administered_dose1_recip_65pluspop_pct': '80.2',
#   'svi_ctgy': 'C',
#   'series_complete_pop_pct_svi': '11',
#   'series_complete_12pluspop_pct_svi': '12',
#   'series_complete_18pluspop_pct_svi': '12',
#   'series_complete_65pluspop_pct_svi': '12',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '51067',
#   'mmwr_week': '42',
#   'recip_county': 'Franklin County',
#   'recip_state': 'VA',
#   'series_complete_pop_pct': '40.1',
#   'series_complete_yes': '22463',
#   'series_complete_12plus': '22444',
#   'series_complete_12pluspop': '45.4',
#   'series_complete_18plus': '21516',
#   'series_complete_18pluspop': '47.3',
#   'series_complete_65plus': '9007',
#   'series_complete_65pluspop': '66.5',
#   'completeness_pct': '83',
#   'administered_dose1_recip': '25392',
#   'administered_dose1_pop_pct': '45.3',
#   'administered_dose1_recip_12plus': '25364',
#   'administered_dose1_recip_12pluspop_pct': '51.3',
#   'administered_dose1_recip_18plus': '24280',
#   'administered_dose1_recip_18pluspop_pct': '53.3',
#   'administered_dose1_recip_65plus': '9677',
#   'administered_dose1_recip_65pluspop_pct': '71.4',
#   'svi_ctgy': 'B',
#   'series_complete_pop_pct_svi': '7',
#   'series_complete_12pluspop_pct_svi': '7',
#   'series_complete_18pluspop_pct_svi': '7',
#   'series_complete_65pluspop_pct_svi': '7',
#   'metro_status': 'Metro',
#   'series_complete_pop_pct_ur_equity': '3',
#   'series_complete_12pluspop_pct_ur_equity': '3',
#   'series_complete_18pluspop_pct_ur_equity': '3',
#   'series_complete_65pluspop_pct_ur_equity': '3'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '51720',
#   'mmwr_week': '42',
#   'recip_county': 'Norton city',
#   'recip_state': 'VA',
#   'series_complete_pop_pct': '30.9',
#   'series_complete_yes': '1230',
#   'series_complete_12plus': '1228',
#   'series_complete_12pluspop': '36.1',
#   'series_complete_18plus': '1179',
#   'series_complete_18pluspop': '37.8',
#   'series_complete_65plus': '407',
#   'series_complete_65pluspop': '54.6',
#   'completeness_pct': '83',
#   'administered_dose1_recip': '1582',
#   'administered_dose1_pop_pct': '39.7',
#   'administered_dose1_recip_12plus': '1575',
#   'administered_dose1_recip_12pluspop_pct': '46.3',
#   'administered_dose1_recip_18plus': '1486',
#   'administered_dose1_recip_18pluspop_pct': '47.6',
#   'administered_dose1_recip_65plus': '496',
#   'administered_dose1_recip_65pluspop_pct': '66.5',
#   'svi_ctgy': 'D',
#   'series_complete_pop_pct_svi': '14',
#   'series_complete_12pluspop_pct_svi': '14',
#   'series_complete_18pluspop_pct_svi': '14',
#   'series_complete_65pluspop_pct_svi': '15',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '6',
#   'series_complete_12pluspop_pct_ur_equity': '6',
#   'series_complete_18pluspop_pct_ur_equity': '6',
#   'series_complete_65pluspop_pct_ur_equity': '7'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '55105',
#   'mmwr_week': '42',
#   'recip_county': 'Rock County',
#   'recip_state': 'WI',
#   'series_complete_pop_pct': '61.3',
#   'series_complete_yes': '100083',
#   'series_complete_12plus': '100078',
#   'series_complete_12pluspop': '71.9',
#   'series_complete_18plus': '94224',
#   'series_complete_18pluspop': '74.8',
#   'series_complete_65plus': '29378',
#   'series_complete_65pluspop': '99.9',
#   'completeness_pct': '97',
#   'administered_dose1_recip': '108411',
#   'administered_dose1_pop_pct': '66.4',
#   'administered_dose1_recip_12plus': '108393',
#   'administered_dose1_recip_12pluspop_pct': '77.8',
#   'administered_dose1_recip_18plus': '101579',
#   'administered_dose1_recip_18pluspop_pct': '80.6',
#   'administered_dose1_recip_65plus': '30745',
#   'administered_dose1_recip_65pluspop_pct': '99.9',
#   'svi_ctgy': 'B',
#   'series_complete_pop_pct_svi': '8',
#   'series_complete_12pluspop_pct_svi': '8',
#   'series_complete_18pluspop_pct_svi': '8',
#   'series_complete_65pluspop_pct_svi': '8',
#   'metro_status': 'Metro',
#   'series_complete_pop_pct_ur_equity': '4',
#   'series_complete_12pluspop_pct_ur_equity': '4',
#   'series_complete_18pluspop_pct_ur_equity': '4',
#   'series_complete_65pluspop_pct_ur_equity': '4'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '18051',
#   'mmwr_week': '42',
#   'recip_county': 'Gibson County',
#   'recip_state': 'IN',
#   'series_complete_pop_pct': '42.8',
#   'series_complete_yes': '14399',
#   'series_complete_12plus': '14398',
#   'series_complete_12pluspop': '50.6',
#   'series_complete_18plus': '13677',
#   'series_complete_18pluspop': '53.3',
#   'series_complete_65plus': '4628',
#   'series_complete_65pluspop': '77.4',
#   'completeness_pct': '98.7',
#   'administered_dose1_recip': '15702',
#   'administered_dose1_pop_pct': '46.7',
#   'administered_dose1_recip_12plus': '15693',
#   'administered_dose1_recip_12pluspop_pct': '55.1',
#   'administered_dose1_recip_18plus': '14863',
#   'administered_dose1_recip_18pluspop_pct': '57.9',
#   'administered_dose1_recip_65plus': '4793',
#   'administered_dose1_recip_65pluspop_pct': '80.1',
#   'svi_ctgy': 'B',
#   'series_complete_pop_pct_svi': '7',
#   'series_complete_12pluspop_pct_svi': '8',
#   'series_complete_18pluspop_pct_svi': '8',
#   'series_complete_65pluspop_pct_svi': '8',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '05019',
#   'mmwr_week': '42',
#   'recip_county': 'Clark County',
#   'recip_state': 'AR',
#   'series_complete_pop_pct': '43.8',
#   'series_complete_yes': '9774',
#   'series_complete_12plus': '9770',
#   'series_complete_12pluspop': '50.2',
#   'series_complete_18plus': '9141',
#   'series_complete_18pluspop': '50.6',
#   'series_complete_65plus': '3013',
#   'series_complete_65pluspop': '80.3',
#   'completeness_pct': '90.2',
#   'administered_dose1_recip': '11231',
#   'administered_dose1_pop_pct': '50.3',
#   'administered_dose1_recip_12plus': '11224',
#   'administered_dose1_recip_12pluspop_pct': '57.6',
#   'administered_dose1_recip_18plus': '10446',
#   'administered_dose1_recip_18pluspop_pct': '57.8',
#   'administered_dose1_recip_65plus': '3267',
#   'administered_dose1_recip_65pluspop_pct': '87.1',
#   'svi_ctgy': 'D',
#   'series_complete_pop_pct_svi': '15',
#   'series_complete_12pluspop_pct_svi': '16',
#   'series_complete_18pluspop_pct_svi': '16',
#   'series_complete_65pluspop_pct_svi': '16',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '38025',
#   'mmwr_week': '42',
#   'recip_county': 'Dunn County',
#   'recip_state': 'ND',
#   'series_complete_pop_pct': '20.7',
#   'series_complete_yes': '914',
#   'series_complete_12plus': '914',
#   'series_complete_12pluspop': '25.1',
#   'series_complete_18plus': '896',
#   'series_complete_18pluspop': '27',
#   'series_complete_65plus': '360',
#   'series_complete_65pluspop': '50.4',
#   'completeness_pct': '95.1',
#   'administered_dose1_recip': '1090',
#   'administered_dose1_pop_pct': '24.6',
#   'administered_dose1_recip_12plus': '1090',
#   'administered_dose1_recip_12pluspop_pct': '29.9',
#   'administered_dose1_recip_18plus': '1066',
#   'administered_dose1_recip_18pluspop_pct': '32.2',
#   'administered_dose1_recip_65plus': '411',
#   'administered_dose1_recip_65pluspop_pct': '57.6',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '1',
#   'series_complete_12pluspop_pct_svi': '1',
#   'series_complete_18pluspop_pct_svi': '1',
#   'series_complete_65pluspop_pct_svi': '3',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '5',
#   'series_complete_12pluspop_pct_ur_equity': '5',
#   'series_complete_18pluspop_pct_ur_equity': '5',
#   'series_complete_65pluspop_pct_ur_equity': '7'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '47111',
#   'mmwr_week': '42',
#   'recip_county': 'Macon County',
#   'recip_state': 'TN',
#   'series_complete_pop_pct': '27.5',
#   'series_complete_yes': '6773',
#   'series_complete_12plus': '6772',
#   'series_complete_12pluspop': '33.0',
#   'series_complete_18plus': '6625',
#   'series_complete_18pluspop': '35.7',
#   'series_complete_65plus': '2511',
#   'series_complete_65pluspop': '63.4',
#   'completeness_pct': '97.9',
#   'administered_dose1_recip': '7689',
#   'administered_dose1_pop_pct': '31.3',
#   'administered_dose1_recip_12plus': '7686',
#   'administered_dose1_recip_12pluspop_pct': '37.5',
#   'administered_dose1_recip_18plus': '7499',
#   'administered_dose1_recip_18pluspop_pct': '40.4',
#   'administered_dose1_recip_65plus': '2663',
#   'administered_dose1_recip_65pluspop_pct': '67.2',
#   'svi_ctgy': 'C',
#   'series_complete_pop_pct_svi': '9',
#   'series_complete_12pluspop_pct_svi': '10',
#   'series_complete_18pluspop_pct_svi': '10',
#   'series_complete_65pluspop_pct_svi': '11',
#   'metro_status': 'Metro',
#   'series_complete_pop_pct_ur_equity': '1',
#   'series_complete_12pluspop_pct_ur_equity': '2',
#   'series_complete_18pluspop_pct_ur_equity': '2',
#   'series_complete_65pluspop_pct_ur_equity': '3'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': 'UNK',
#   'mmwr_week': '42',
#   'recip_county': 'Unknown County',
#   'recip_state': 'PW',
#   'series_complete_pop_pct': '0',
#   'series_complete_yes': '15644',
#   'series_complete_12plus': '15644',
#   'series_complete_12pluspop': '0.0',
#   'series_complete_18plus': '14365',
#   'series_complete_18pluspop': '0',
#   'series_complete_65plus': '1710',
#   'series_complete_65pluspop': '0',
#   'completeness_pct': '0',
#   'administered_dose1_recip': '17937',
#   'administered_dose1_pop_pct': '0',
#   'administered_dose1_recip_12plus': '17937',
#   'administered_dose1_recip_12pluspop_pct': '0.0',
#   'administered_dose1_recip_18plus': '16586',
#   'administered_dose1_recip_18pluspop_pct': '0',
#   'administered_dose1_recip_65plus': '1788',
#   'administered_dose1_recip_65pluspop_pct': '0'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '27009',
#   'mmwr_week': '42',
#   'recip_county': 'Benton County',
#   'recip_state': 'MN',
#   'series_complete_pop_pct': '35',
#   'series_complete_yes': '14315',
#   'series_complete_12plus': '14295',
#   'series_complete_12pluspop': '42.2',
#   'series_complete_18plus': '13263',
#   'series_complete_18pluspop': '43.5',
#   'series_complete_65plus': '3659',
#   'series_complete_65pluspop': '62.5',
#   'completeness_pct': '94',
#   'administered_dose1_recip': '15708',
#   'administered_dose1_pop_pct': '38.4',
#   'administered_dose1_recip_12plus': '15672',
#   'administered_dose1_recip_12pluspop_pct': '46.2',
#   'administered_dose1_recip_18plus': '14574',
#   'administered_dose1_recip_18pluspop_pct': '47.8',
#   'administered_dose1_recip_65plus': '3973',
#   'administered_dose1_recip_65pluspop_pct': '67.8',
#   'svi_ctgy': 'B',
#   'series_complete_pop_pct_svi': '6',
#   'series_complete_12pluspop_pct_svi': '7',
#   'series_complete_18pluspop_pct_svi': '7',
#   'series_complete_65pluspop_pct_svi': '7',
#   'metro_status': 'Metro',
#   'series_complete_pop_pct_ur_equity': '2',
#   'series_complete_12pluspop_pct_ur_equity': '3',
#   'series_complete_18pluspop_pct_ur_equity': '3',
#   'series_complete_65pluspop_pct_ur_equity': '3'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '18107',
#   'mmwr_week': '42',
#   'recip_county': 'Montgomery County',
#   'recip_state': 'IN',
#   'series_complete_pop_pct': '41.7',
#   'series_complete_yes': '15975',
#   'series_complete_12plus': '15975',
#   'series_complete_12pluspop': '48.9',
#   'series_complete_18plus': '15248',
#   'series_complete_18pluspop': '51.4',
#   'series_complete_65plus': '5402',
#   'series_complete_65pluspop': '77',
#   'completeness_pct': '98.7',
#   'administered_dose1_recip': '17150',
#   'administered_dose1_pop_pct': '44.7',
#   'administered_dose1_recip_12plus': '17150',
#   'administered_dose1_recip_12pluspop_pct': '52.5',
#   'administered_dose1_recip_18plus': '16312',
#   'administered_dose1_recip_18pluspop_pct': '55',
#   'administered_dose1_recip_65plus': '5585',
#   'administered_dose1_recip_65pluspop_pct': '79.6',
#   'svi_ctgy': 'B',
#   'series_complete_pop_pct_svi': '7',
#   'series_complete_12pluspop_pct_svi': '7',
#   'series_complete_18pluspop_pct_svi': '8',
#   'series_complete_65pluspop_pct_svi': '8',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '7',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '20121',
#   'mmwr_week': '42',
#   'recip_county': 'Miami County',
#   'recip_state': 'KS',
#   'series_complete_pop_pct': '42.6',
#   'series_complete_yes': '14583',
#   'series_complete_12plus': '14583',
#   'series_complete_12pluspop': '50.4',
#   'series_complete_18plus': '13629',
#   'series_complete_18pluspop': '52.7',
#   'series_complete_65plus': '4329',
#   'series_complete_65pluspop': '74.1',
#   'completeness_pct': '93.6',
#   'administered_dose1_recip': '16106',
#   'administered_dose1_pop_pct': '47',
#   'administered_dose1_recip_12plus': '16106',
#   'administered_dose1_recip_12pluspop_pct': '55.7',
#   'administered_dose1_recip_18plus': '15012',
#   'administered_dose1_recip_18pluspop_pct': '58',
#   'administered_dose1_recip_65plus': '4734',
#   'administered_dose1_recip_65pluspop_pct': '81',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '3',
#   'series_complete_12pluspop_pct_svi': '4',
#   'series_complete_18pluspop_pct_svi': '4',
#   'series_complete_65pluspop_pct_svi': '4',
#   'metro_status': 'Metro',
#   'series_complete_pop_pct_ur_equity': '3',
#   'series_complete_12pluspop_pct_ur_equity': '4',
#   'series_complete_18pluspop_pct_ur_equity': '4',
#   'series_complete_65pluspop_pct_ur_equity': '4'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '40093',
#   'mmwr_week': '42',
#   'recip_county': 'Major County',
#   'recip_state': 'OK',
#   'series_complete_pop_pct': '43.9',
#   'series_complete_yes': '3349',
#   'series_complete_12plus': '3349',
#   'series_complete_12pluspop': '52.8',
#   'series_complete_18plus': '3240',
#   'series_complete_18pluspop': '57.2',
#   'series_complete_65plus': '1368',
#   'series_complete_65pluspop': '87.5',
#   'completeness_pct': '93.8',
#   'administered_dose1_recip': '3780',
#   'administered_dose1_pop_pct': '49.5',
#   'administered_dose1_recip_12plus': '3780',
#   'administered_dose1_recip_12pluspop_pct': '59.6',
#   'administered_dose1_recip_18plus': '3653',
#   'administered_dose1_recip_18pluspop_pct': '64.5',
#   'administered_dose1_recip_65plus': '1490',
#   'administered_dose1_recip_65pluspop_pct': '95.3',
#   'svi_ctgy': 'B',
#   'series_complete_pop_pct_svi': '7',
#   'series_complete_12pluspop_pct_svi': '8',
#   'series_complete_18pluspop_pct_svi': '8',
#   'series_complete_65pluspop_pct_svi': '8',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '53041',
#   'mmwr_week': '42',
#   'recip_county': 'Lewis County',
#   'recip_state': 'WA',
#   'series_complete_pop_pct': '45.2',
#   'series_complete_yes': '36488',
#   'series_complete_12plus': '36488',
#   'series_complete_12pluspop': '52.7',
#   'series_complete_18plus': '34666',
#   'series_complete_18pluspop': '54.6',
#   'series_complete_65plus': '12320',
#   'series_complete_65pluspop': '71.6',
#   'completeness_pct': '96.1',
#   'administered_dose1_recip': '40308',
#   'administered_dose1_pop_pct': '49.9',
#   'administered_dose1_recip_12plus': '40307',
#   'administered_dose1_recip_12pluspop_pct': '58.2',
#   'administered_dose1_recip_18plus': '38195',
#   'administered_dose1_recip_18pluspop_pct': '60.2',
#   'administered_dose1_recip_65plus': '13103',
#   'administered_dose1_recip_65pluspop_pct': '76.2',
#   'svi_ctgy': 'D',
#   'series_complete_pop_pct_svi': '15',
#   'series_complete_12pluspop_pct_svi': '16',
#   'series_complete_18pluspop_pct_svi': '16',
#   'series_complete_65pluspop_pct_svi': '16',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '31051',
#   'mmwr_week': '42',
#   'recip_county': 'Dixon County',
#   'recip_state': 'NE',
#   'series_complete_pop_pct': '38.6',
#   'series_complete_yes': '2173',
#   'series_complete_12plus': '2173',
#   'series_complete_12pluspop': '46.4',
#   'series_complete_18plus': '2084',
#   'series_complete_18pluspop': '49.7',
#   'series_complete_65plus': '688',
#   'series_complete_65pluspop': '59',
#   'completeness_pct': '89.7',
#   'administered_dose1_pop_pct': '0',
#   'administered_dose1_recip_12pluspop_pct': '0.0',
#   'administered_dose1_recip_18pluspop_pct': '0',
#   'administered_dose1_recip_65pluspop_pct': '0',
#   'svi_ctgy': 'B',
#   'series_complete_pop_pct_svi': '6',
#   'series_complete_12pluspop_pct_svi': '7',
#   'series_complete_18pluspop_pct_svi': '7',
#   'series_complete_65pluspop_pct_svi': '7',
#   'metro_status': 'Metro',
#   'series_complete_pop_pct_ur_equity': '2',
#   'series_complete_12pluspop_pct_ur_equity': '3',
#   'series_complete_18pluspop_pct_ur_equity': '3',
#   'series_complete_65pluspop_pct_ur_equity': '3'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '27149',
#   'mmwr_week': '42',
#   'recip_county': 'Stevens County',
#   'recip_state': 'MN',
#   'series_complete_pop_pct': '49.9',
#   'series_complete_yes': '4892',
#   'series_complete_12plus': '4880',
#   'series_complete_12pluspop': '58.2',
#   'series_complete_18plus': '4611',
#   'series_complete_18pluspop': '59.9',
#   'series_complete_65plus': '1433',
#   'series_complete_65pluspop': '84.2',
#   'completeness_pct': '94',
#   'administered_dose1_recip': '5242',
#   'administered_dose1_pop_pct': '53.5',
#   'administered_dose1_recip_12plus': '5225',
#   'administered_dose1_recip_12pluspop_pct': '62.3',
#   'administered_dose1_recip_18plus': '4947',
#   'administered_dose1_recip_18pluspop_pct': '64.2',
#   'administered_dose1_recip_65plus': '1524',
#   'administered_dose1_recip_65pluspop_pct': '89.5',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '3',
#   'series_complete_12pluspop_pct_svi': '4',
#   'series_complete_18pluspop_pct_svi': '4',
#   'series_complete_65pluspop_pct_svi': '4',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '72063',
#   'mmwr_week': '42',
#   'recip_county': 'Gurabo Municipio',
#   'recip_state': 'PR',
#   'series_complete_pop_pct': '58.3',
#   'series_complete_yes': '27449',
#   'series_complete_12plus': '27441',
#   'series_complete_12pluspop': '65.3',
#   'series_complete_18plus': '25372',
#   'series_complete_18pluspop': '65.6',
#   'series_complete_65plus': '6100',
#   'series_complete_65pluspop': '76.2',
#   'completeness_pct': '95.9',
#   'administered_dose1_recip': '30318',
#   'administered_dose1_pop_pct': '64.4',
#   'administered_dose1_recip_12plus': '30296',
#   'administered_dose1_recip_12pluspop_pct': '72.1',
#   'administered_dose1_recip_18plus': '27938',
#   'administered_dose1_recip_18pluspop_pct': '72.3',
#   'administered_dose1_recip_65plus': '6767',
#   'administered_dose1_recip_65pluspop_pct': '84.5',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '4',
#   'series_complete_12pluspop_pct_svi': '4',
#   'series_complete_18pluspop_pct_svi': '4',
#   'series_complete_65pluspop_pct_svi': '4',
#   'metro_status': 'Metro',
#   'series_complete_pop_pct_ur_equity': '4',
#   'series_complete_12pluspop_pct_ur_equity': '4',
#   'series_complete_18pluspop_pct_ur_equity': '4',
#   'series_complete_65pluspop_pct_ur_equity': '4'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '08029',
#   'mmwr_week': '42',
#   'recip_county': 'Delta County',
#   'recip_state': 'CO',
#   'series_complete_pop_pct': '42.3',
#   'series_complete_yes': '13177',
#   'series_complete_12plus': '13171',
#   'series_complete_12pluspop': '48.2',
#   'series_complete_18plus': '12723',
#   'series_complete_18pluspop': '50.8',
#   'series_complete_65plus': '6009',
#   'series_complete_65pluspop': '71.9',
#   'completeness_pct': '97.3',
#   'administered_dose1_recip': '14504',
#   'administered_dose1_pop_pct': '46.5',
#   'administered_dose1_recip_12plus': '14491',
#   'administered_dose1_recip_12pluspop_pct': '53.1',
#   'administered_dose1_recip_18plus': '13959',
#   'administered_dose1_recip_18pluspop_pct': '55.7',
#   'administered_dose1_recip_65plus': '6564',
#   'administered_dose1_recip_65pluspop_pct': '78.6',
#   'svi_ctgy': 'C',
#   'series_complete_pop_pct_svi': '11',
#   'series_complete_12pluspop_pct_svi': '11',
#   'series_complete_18pluspop_pct_svi': '12',
#   'series_complete_65pluspop_pct_svi': '12',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '7',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '48301',
#   'mmwr_week': '42',
#   'recip_county': 'Loving County',
#   'recip_state': 'TX',
#   'series_complete_pop_pct': '0',
#   'series_complete_yes': '0',
#   'series_complete_12plus': '0',
#   'series_complete_12pluspop': '0.0',
#   'series_complete_18plus': '0',
#   'series_complete_18pluspop': '0',
#   'series_complete_65plus': '0',
#   'series_complete_65pluspop': '0',
#   'completeness_pct': '0',
#   'administered_dose1_recip': '0',
#   'administered_dose1_pop_pct': '0',
#   'administered_dose1_recip_12plus': '0',
#   'administered_dose1_recip_12pluspop_pct': '0.0',
#   'administered_dose1_recip_18plus': '0',
#   'administered_dose1_recip_18pluspop_pct': '0',
#   'administered_dose1_recip_65plus': '0',
#   'administered_dose1_recip_65pluspop_pct': '0',
#   'svi_ctgy': 'D',
#   'metro_status': 'Non-metro'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '33019',
#   'mmwr_week': '42',
#   'recip_county': 'Sullivan County',
#   'recip_state': 'NH',
#   'series_complete_pop_pct': '56.7',
#   'series_complete_yes': '24464',
#   'series_complete_12plus': '24441',
#   'series_complete_12pluspop': '64.2',
#   'series_complete_18plus': '23318',
#   'series_complete_18pluspop': '66.4',
#   'series_complete_65plus': '7880',
#   'series_complete_65pluspop': '82.7',
#   'completeness_pct': '94.1',
#   'administered_dose1_recip': '28251',
#   'administered_dose1_pop_pct': '65.5',
#   'administered_dose1_recip_12plus': '28200',
#   'administered_dose1_recip_12pluspop_pct': '74.1',
#   'administered_dose1_recip_18plus': '26749',
#   'administered_dose1_recip_18pluspop_pct': '76.2',
#   'administered_dose1_recip_65plus': '9198',
#   'administered_dose1_recip_65pluspop_pct': '96.5',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '4',
#   'series_complete_12pluspop_pct_svi': '4',
#   'series_complete_18pluspop_pct_svi': '4',
#   'series_complete_65pluspop_pct_svi': '4',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '8',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '04012',
#   'mmwr_week': '42',
#   'recip_county': 'La Paz County',
#   'recip_state': 'AZ',
#   'series_complete_pop_pct': '41.5',
#   'series_complete_yes': '8767',
#   'series_complete_12plus': '8766',
#   'series_complete_12pluspop': '46.6',
#   'series_complete_18plus': '8321',
#   'series_complete_18pluspop': '47.3',
#   'series_complete_65plus': '4556',
#   'series_complete_65pluspop': '54.3',
#   'completeness_pct': '97.6',
#   'administered_dose1_recip': '10462',
#   'administered_dose1_pop_pct': '49.6',
#   'administered_dose1_recip_12plus': '10460',
#   'administered_dose1_recip_12pluspop_pct': '55.6',
#   'administered_dose1_recip_18plus': '9827',
#   'administered_dose1_recip_18pluspop_pct': '55.8',
#   'administered_dose1_recip_65plus': '5044',
#   'administered_dose1_recip_65pluspop_pct': '60.1',
#   'svi_ctgy': 'D',
#   'series_complete_pop_pct_svi': '15',
#   'series_complete_12pluspop_pct_svi': '15',
#   'series_complete_18pluspop_pct_svi': '15',
#   'series_complete_65pluspop_pct_svi': '15',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '7',
#   'series_complete_18pluspop_pct_ur_equity': '7',
#   'series_complete_65pluspop_pct_ur_equity': '7'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '40043',
#   'mmwr_week': '42',
#   'recip_county': 'Dewey County',
#   'recip_state': 'OK',
#   'series_complete_pop_pct': '23.3',
#   'series_complete_yes': '1139',
#   'series_complete_12plus': '1139',
#   'series_complete_12pluspop': '28.5',
#   'series_complete_18plus': '1109',
#   'series_complete_18pluspop': '31.2',
#   'series_complete_65plus': '523',
#   'series_complete_65pluspop': '58.9',
#   'completeness_pct': '93.8',
#   'administered_dose1_recip': '1242',
#   'administered_dose1_pop_pct': '25.4',
#   'administered_dose1_recip_12plus': '1242',
#   'administered_dose1_recip_12pluspop_pct': '31.1',
#   'administered_dose1_recip_18plus': '1203',
#   'administered_dose1_recip_18pluspop_pct': '33.9',
#   'administered_dose1_recip_65plus': '544',
#   'administered_dose1_recip_65pluspop_pct': '61.3',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '1',
#   'series_complete_12pluspop_pct_svi': '1',
#   'series_complete_18pluspop_pct_svi': '2',
#   'series_complete_65pluspop_pct_svi': '3',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '5',
#   'series_complete_12pluspop_pct_ur_equity': '5',
#   'series_complete_18pluspop_pct_ur_equity': '6',
#   'series_complete_65pluspop_pct_ur_equity': '7'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '36121',
#   'mmwr_week': '42',
#   'recip_county': 'Wyoming County',
#   'recip_state': 'NY',
#   'series_complete_pop_pct': '45.6',
#   'series_complete_yes': '18188',
#   'series_complete_12plus': '18187',
#   'series_complete_12pluspop': '51.8',
#   'series_complete_18plus': '17298',
#   'series_complete_18pluspop': '53.4',
#   'series_complete_65plus': '5702',
#   'series_complete_65pluspop': '76.8',
#   'completeness_pct': '97.6',
#   'administered_dose1_recip': '19341',
#   'administered_dose1_pop_pct': '48.5',
#   'administered_dose1_recip_12plus': '19339',
#   'administered_dose1_recip_12pluspop_pct': '55.1',
#   'administered_dose1_recip_18plus': '18375',
#   'administered_dose1_recip_18pluspop_pct': '56.7',
#   'administered_dose1_recip_65plus': '6031',
#   'administered_dose1_recip_65pluspop_pct': '81.2',
#   'svi_ctgy': 'B',
#   'series_complete_pop_pct_svi': '7',
#   'series_complete_12pluspop_pct_svi': '8',
#   'series_complete_18pluspop_pct_svi': '8',
#   'series_complete_65pluspop_pct_svi': '8',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '35031',
#   'mmwr_week': '42',
#   'recip_county': 'McKinley County',
#   'recip_state': 'NM',
#   'series_complete_pop_pct': '99.9',
#   'series_complete_yes': '71941',
#   'series_complete_12plus': '71926',
#   'series_complete_12pluspop': '99.9',
#   'series_complete_18plus': '60999',
#   'series_complete_18pluspop': '99.9',
#   'series_complete_65plus': '11875',
#   'series_complete_65pluspop': '99.9',
#   'completeness_pct': '84.4',
#   'administered_dose1_recip': '79619',
#   'administered_dose1_pop_pct': '99.9',
#   'administered_dose1_recip_12plus': '79570',
#   'administered_dose1_recip_12pluspop_pct': '99.9',
#   'administered_dose1_recip_18plus': '67490',
#   'administered_dose1_recip_18pluspop_pct': '99.9',
#   'administered_dose1_recip_65plus': '13129',
#   'administered_dose1_recip_65pluspop_pct': '99.9',
#   'svi_ctgy': 'D',
#   'series_complete_pop_pct_svi': '16',
#   'series_complete_12pluspop_pct_svi': '16',
#   'series_complete_18pluspop_pct_svi': '16',
#   'series_complete_65pluspop_pct_svi': '16',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '8',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '38051',
#   'mmwr_week': '42',
#   'recip_county': 'McIntosh County',
#   'recip_state': 'ND',
#   'series_complete_pop_pct': '38.2',
#   'series_complete_yes': '953',
#   'series_complete_12plus': '953',
#   'series_complete_12pluspop': '43.4',
#   'series_complete_18plus': '932',
#   'series_complete_18pluspop': '45.8',
#   'series_complete_65plus': '485',
#   'series_complete_65pluspop': '60.4',
#   'completeness_pct': '95.1',
#   'administered_dose1_recip': '1128',
#   'administered_dose1_pop_pct': '45.2',
#   'administered_dose1_recip_12plus': '1128',
#   'administered_dose1_recip_12pluspop_pct': '51.4',
#   'administered_dose1_recip_18plus': '1103',
#   'administered_dose1_recip_18pluspop_pct': '54.2',
#   'administered_dose1_recip_65plus': '567',
#   'administered_dose1_recip_65pluspop_pct': '70.6',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '2',
#   'series_complete_12pluspop_pct_svi': '3',
#   'series_complete_18pluspop_pct_svi': '3',
#   'series_complete_65pluspop_pct_svi': '3',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '6',
#   'series_complete_12pluspop_pct_ur_equity': '7',
#   'series_complete_18pluspop_pct_ur_equity': '7',
#   'series_complete_65pluspop_pct_ur_equity': '7'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '19061',
#   'mmwr_week': '42',
#   'recip_county': 'Dubuque County',
#   'recip_state': 'IA',
#   'series_complete_pop_pct': '58.3',
#   'series_complete_yes': '56702',
#   'series_complete_12plus': '56702',
#   'series_complete_12pluspop': '68.6',
#   'series_complete_18plus': '53403',
#   'series_complete_18pluspop': '71',
#   'series_complete_65plus': '17022',
#   'series_complete_65pluspop': '95.5',
#   'completeness_pct': '97.5',
#   'administered_dose1_recip': '59523',
# ...
#   'series_complete_12pluspop_pct_svi': '12',
#   'series_complete_18pluspop_pct_svi': '12',
#   'series_complete_65pluspop_pct_svi': '12',
#   'metro_status': 'Metro',
#   'series_complete_pop_pct_ur_equity': '3',
#   'series_complete_12pluspop_pct_ur_equity': '4',
#   'series_complete_18pluspop_pct_ur_equity': '4',
#   'series_complete_65pluspop_pct_ur_equity': '4'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '29141',
#   'mmwr_week': '42',
#   'recip_county': 'Morgan County',
#   'recip_state': 'MO',
#   'series_complete_pop_pct': '34.1',
#   'series_complete_yes': '7033',
#   'series_complete_12plus': '7033',
#   'series_complete_12pluspop': '40.3',
#   'series_complete_18plus': '6854',
#   'series_complete_18pluspop': '43.2',
#   'series_complete_65plus': '3427',
#   'series_complete_65pluspop': '70.8',
#   'completeness_pct': '91.2',
#   'administered_dose1_recip': '7836',
#   'administered_dose1_pop_pct': '38',
#   'administered_dose1_recip_12plus': '7836',
#   'administered_dose1_recip_12pluspop_pct': '44.9',
#   'administered_dose1_recip_18plus': '7618',
#   'administered_dose1_recip_18pluspop_pct': '48.1',
#   'administered_dose1_recip_65plus': '3688',
#   'administered_dose1_recip_65pluspop_pct': '76.2',
#   'svi_ctgy': 'C',
#   'series_complete_pop_pct_svi': '10',
#   'series_complete_12pluspop_pct_svi': '11',
#   'series_complete_18pluspop_pct_svi': '11',
#   'series_complete_65pluspop_pct_svi': '12',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '6',
#   'series_complete_12pluspop_pct_ur_equity': '7',
#   'series_complete_18pluspop_pct_ur_equity': '7',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '47071',
#   'mmwr_week': '42',
#   'recip_county': 'Hardin County',
#   'recip_state': 'TN',
#   'series_complete_pop_pct': '36.2',
#   'series_complete_yes': '9275',
#   'series_complete_12plus': '9275',
#   'series_complete_12pluspop': '41.6',
#   'series_complete_18plus': '8999',
#   'series_complete_18pluspop': '44.1',
#   'series_complete_65plus': '3787',
#   'series_complete_65pluspop': '63.3',
#   'completeness_pct': '97.9',
#   'administered_dose1_recip': '10616',
#   'administered_dose1_pop_pct': '41.4',
#   'administered_dose1_recip_12plus': '10614',
#   'administered_dose1_recip_12pluspop_pct': '47.6',
#   'administered_dose1_recip_18plus': '10251',
#   'administered_dose1_recip_18pluspop_pct': '50.2',
#   'administered_dose1_recip_65plus': '4135',
#   'administered_dose1_recip_65pluspop_pct': '69.1',
#   'svi_ctgy': 'C',
#   'series_complete_pop_pct_svi': '10',
#   'series_complete_12pluspop_pct_svi': '11',
#   'series_complete_18pluspop_pct_svi': '11',
#   'series_complete_65pluspop_pct_svi': '11',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '6',
#   'series_complete_12pluspop_pct_ur_equity': '7',
#   'series_complete_18pluspop_pct_ur_equity': '7',
#   'series_complete_65pluspop_pct_ur_equity': '7'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '05049',
#   'mmwr_week': '42',
#   'recip_county': 'Fulton County',
#   'recip_state': 'AR',
#   'series_complete_pop_pct': '28.8',
#   'series_complete_yes': '3591',
#   'series_complete_12plus': '3591',
#   'series_complete_12pluspop': '33.2',
#   'series_complete_18plus': '3426',
#   'series_complete_18pluspop': '34.8',
#   'series_complete_65plus': '1379',
#   'series_complete_65pluspop': '42.4',
#   'completeness_pct': '90.2',
#   'administered_dose1_recip': '4109',
#   'administered_dose1_pop_pct': '32.9',
#   'administered_dose1_recip_12plus': '4108',
#   'administered_dose1_recip_12pluspop_pct': '38.0',
#   'administered_dose1_recip_18plus': '3863',
#   'administered_dose1_recip_18pluspop_pct': '39.2',
#   'administered_dose1_recip_65plus': '1519',
#   'administered_dose1_recip_65pluspop_pct': '46.8',
#   'svi_ctgy': 'C',
#   'series_complete_pop_pct_svi': '9',
#   'series_complete_12pluspop_pct_svi': '10',
#   'series_complete_18pluspop_pct_svi': '10',
#   'series_complete_65pluspop_pct_svi': '10',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '5',
#   'series_complete_12pluspop_pct_ur_equity': '6',
#   'series_complete_18pluspop_pct_ur_equity': '6',
#   'series_complete_65pluspop_pct_ur_equity': '6'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '48079',
#   'mmwr_week': '42',
#   'recip_county': 'Cochran County',
#   'recip_state': 'TX',
#   'series_complete_pop_pct': '0',
#   'series_complete_yes': '0',
#   'series_complete_12plus': '0',
#   'series_complete_12pluspop': '0.0',
#   'series_complete_18plus': '0',
#   'series_complete_18pluspop': '0',
#   'series_complete_65plus': '0',
#   'series_complete_65pluspop': '0',
#   'completeness_pct': '0',
#   'administered_dose1_recip': '0',
#   'administered_dose1_pop_pct': '0',
#   'administered_dose1_recip_12plus': '0',
#   'administered_dose1_recip_12pluspop_pct': '0.0',
#   'administered_dose1_recip_18plus': '0',
#   'administered_dose1_recip_18pluspop_pct': '0',
#   'administered_dose1_recip_65plus': '0',
#   'administered_dose1_recip_65pluspop_pct': '0',
#   'svi_ctgy': 'D',
#   'metro_status': 'Non-metro'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '17121',
#   'mmwr_week': '42',
#   'recip_county': 'Marion County',
#   'recip_state': 'IL',
#   'series_complete_pop_pct': '37.1',
#   'series_complete_yes': '13797',
#   'series_complete_12plus': '13791',
#   'series_complete_12pluspop': '43.9',
#   'series_complete_18plus': '13306',
#   'series_complete_18pluspop': '46.6',
#   'series_complete_65plus': '5403',
#   'series_complete_65pluspop': '73.4',
#   'completeness_pct': '97.8',
#   'administered_dose1_recip': '16953',
#   'administered_dose1_pop_pct': '45.6',
#   'administered_dose1_recip_12plus': '16934',
#   'administered_dose1_recip_12pluspop_pct': '53.9',
#   'administered_dose1_recip_18plus': '16262',
#   'administered_dose1_recip_18pluspop_pct': '56.9',
#   'administered_dose1_recip_65plus': '6493',
#   'administered_dose1_recip_65pluspop_pct': '88.1',
#   'svi_ctgy': 'C',
#   'series_complete_pop_pct_svi': '10',
#   'series_complete_12pluspop_pct_svi': '11',
#   'series_complete_18pluspop_pct_svi': '11',
#   'series_complete_65pluspop_pct_svi': '12',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '6',
#   'series_complete_12pluspop_pct_ur_equity': '7',
#   'series_complete_18pluspop_pct_ur_equity': '7',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '31117',
#   'mmwr_week': '42',
#   'recip_county': 'McPherson County',
#   'recip_state': 'NE',
#   'series_complete_pop_pct': '12.6',
#   'series_complete_yes': '62',
#   'series_complete_12plus': '62',
#   'series_complete_12pluspop': '13.7',
#   'series_complete_18plus': '62',
#   'series_complete_18pluspop': '15.3',
#   'series_complete_65plus': '36',
#   'series_complete_65pluspop': '30.3',
#   'completeness_pct': '89.7',
#   'administered_dose1_pop_pct': '0',
#   'administered_dose1_recip_12pluspop_pct': '0.0',
#   'administered_dose1_recip_18pluspop_pct': '0',
#   'administered_dose1_recip_65pluspop_pct': '0',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '1',
#   'series_complete_12pluspop_pct_svi': '1',
#   'series_complete_18pluspop_pct_svi': '1',
#   'series_complete_65pluspop_pct_svi': '2',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '5',
#   'series_complete_12pluspop_pct_ur_equity': '5',
#   'series_complete_18pluspop_pct_ur_equity': '5',
#   'series_complete_65pluspop_pct_ur_equity': '6'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '19139',
#   'mmwr_week': '42',
#   'recip_county': 'Muscatine County',
#   'recip_state': 'IA',
#   'series_complete_pop_pct': '53.7',
#   'series_complete_yes': '22924',
#   'series_complete_12plus': '22924',
#   'series_complete_12pluspop': '64.1',
#   'series_complete_18plus': '21456',
#   'series_complete_18pluspop': '66.8',
#   'series_complete_65plus': '6455',
#   'series_complete_65pluspop': '87.9',
#   'completeness_pct': '97.5',
#   'administered_dose1_recip': '24497',
#   'administered_dose1_pop_pct': '57.4',
#   'administered_dose1_recip_12plus': '24495',
#   'administered_dose1_recip_12pluspop_pct': '68.5',
#   'administered_dose1_recip_18plus': '22810',
#   'administered_dose1_recip_18pluspop_pct': '71',
#   'administered_dose1_recip_65plus': '6711',
#   'administered_dose1_recip_65pluspop_pct': '91.4',
#   'svi_ctgy': 'B',
#   'series_complete_pop_pct_svi': '8',
#   'series_complete_12pluspop_pct_svi': '8',
#   'series_complete_18pluspop_pct_svi': '8',
#   'series_complete_65pluspop_pct_svi': '8',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '8',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '04027',
#   'mmwr_week': '42',
#   'recip_county': 'Yuma County',
#   'recip_state': 'AZ',
#   'series_complete_pop_pct': '57.7',
#   'series_complete_yes': '123253',
#   'series_complete_12plus': '123230',
#   'series_complete_12pluspop': '69.3',
#   'series_complete_18plus': '112986',
#   'series_complete_18pluspop': '70.5',
#   'series_complete_65plus': '29329',
#   'series_complete_65pluspop': '71',
#   'completeness_pct': '97.6',
#   'administered_dose1_recip': '141976',
#   'administered_dose1_pop_pct': '66.4',
#   'administered_dose1_recip_12plus': '141915',
#   'administered_dose1_recip_12pluspop_pct': '79.8',
#   'administered_dose1_recip_18plus': '129135',
#   'administered_dose1_recip_18pluspop_pct': '80.6',
#   'administered_dose1_recip_65plus': '32772',
#   'administered_dose1_recip_65pluspop_pct': '79.3',
#   'svi_ctgy': 'D',
#   'series_complete_pop_pct_svi': '16',
#   'series_complete_12pluspop_pct_svi': '16',
#   'series_complete_18pluspop_pct_svi': '16',
#   'series_complete_65pluspop_pct_svi': '16',
#   'metro_status': 'Metro',
#   'series_complete_pop_pct_ur_equity': '4',
#   'series_complete_12pluspop_pct_ur_equity': '4',
#   'series_complete_18pluspop_pct_ur_equity': '4',
#   'series_complete_65pluspop_pct_ur_equity': '4'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '29155',
#   'mmwr_week': '42',
#   'recip_county': 'Pemiscot County',
#   'recip_state': 'MO',
#   'series_complete_pop_pct': '25',
#   'series_complete_yes': '3956',
#   'series_complete_12plus': '3956',
#   'series_complete_12pluspop': '30.3',
#   'series_complete_18plus': '3842',
#   'series_complete_18pluspop': '32.6',
#   'series_complete_65plus': '1197',
#   'series_complete_65pluspop': '43',
#   'completeness_pct': '91.2',
#   'administered_dose1_recip': '5435',
#   'administered_dose1_pop_pct': '34.4',
#   'administered_dose1_recip_12plus': '5426',
#   'administered_dose1_recip_12pluspop_pct': '41.5',
#   'administered_dose1_recip_18plus': '5258',
#   'administered_dose1_recip_18pluspop_pct': '44.7',
#   'administered_dose1_recip_65plus': '1834',
#   'administered_dose1_recip_65pluspop_pct': '65.9',
#   'svi_ctgy': 'D',
#   'series_complete_pop_pct_svi': '13',
#   'series_complete_12pluspop_pct_svi': '14',
#   'series_complete_18pluspop_pct_svi': '14',
#   'series_complete_65pluspop_pct_svi': '14',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '5',
#   'series_complete_12pluspop_pct_ur_equity': '6',
#   'series_complete_18pluspop_pct_ur_equity': '6',
#   'series_complete_65pluspop_pct_ur_equity': '6'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '41055',
#   'mmwr_week': '42',
#   'recip_county': 'Sherman County',
#   'recip_state': 'OR',
#   'series_complete_pop_pct': '51.9',
#   'series_complete_yes': '924',
#   'series_complete_12plus': '923',
#   'series_complete_12pluspop': '59.4',
#   'series_complete_18plus': '898',
#   'series_complete_18pluspop': '62.2',
#   'series_complete_65plus': '338',
#   'series_complete_65pluspop': '74.6',
#   'completeness_pct': '97.8',
#   'administered_dose1_recip': '1034',
#   'administered_dose1_pop_pct': '58.1',
#   'administered_dose1_recip_12plus': '1033',
#   'administered_dose1_recip_12pluspop_pct': '66.4',
#   'administered_dose1_recip_18plus': '996',
#   'administered_dose1_recip_18pluspop_pct': '69',
#   'administered_dose1_recip_65plus': '366',
#   'administered_dose1_recip_65pluspop_pct': '80.8',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '4',
#   'series_complete_12pluspop_pct_svi': '4',
#   'series_complete_18pluspop_pct_svi': '4',
#   'series_complete_65pluspop_pct_svi': '4',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '8',
#   'series_complete_12pluspop_pct_ur_equity': '8',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '06085',
#   'mmwr_week': '42',
#   'recip_county': 'Santa Clara County',
#   'recip_state': 'CA',
#   'series_complete_pop_pct': '75',
#   'series_complete_yes': '1446849',
#   'series_complete_12plus': '1442122',
#   'series_complete_12pluspop': '87.1',
#   'series_complete_18plus': '1322761',
#   'series_complete_18pluspop': '87.5',
#   'series_complete_65plus': '242182',
#   'series_complete_65pluspop': '90.3',
#   'completeness_pct': '97.4',
#   'administered_dose1_recip': '1585480',
#   'administered_dose1_pop_pct': '82.2',
#   'administered_dose1_recip_12plus': '1578877',
#   'administered_dose1_recip_12pluspop_pct': '95.4',
#   'administered_dose1_recip_18plus': '1451423',
#   'administered_dose1_recip_18pluspop_pct': '96',
#   'administered_dose1_recip_65plus': '268653',
#   'administered_dose1_recip_65pluspop_pct': '99.9',
#   'svi_ctgy': 'B',
#   'series_complete_pop_pct_svi': '8',
#   'series_complete_12pluspop_pct_svi': '8',
#   'series_complete_18pluspop_pct_svi': '8',
#   'series_complete_65pluspop_pct_svi': '8',
#   'metro_status': 'Metro',
#   'series_complete_pop_pct_ur_equity': '4',
#   'series_complete_12pluspop_pct_ur_equity': '4',
#   'series_complete_18pluspop_pct_ur_equity': '4',
#   'series_complete_65pluspop_pct_ur_equity': '4'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '19075',
#   'mmwr_week': '42',
#   'recip_county': 'Grundy County',
#   'recip_state': 'IA',
#   'series_complete_pop_pct': '55.9',
#   'series_complete_yes': '6832',
#   'series_complete_12plus': '6832',
#   'series_complete_12pluspop': '65.4',
#   'series_complete_18plus': '6515',
#   'series_complete_18pluspop': '68.9',
#   'series_complete_65plus': '2327',
#   'series_complete_65pluspop': '89.7',
#   'completeness_pct': '97.5',
#   'administered_dose1_recip': '7300',
#   'administered_dose1_pop_pct': '59.7',
#   'administered_dose1_recip_12plus': '7300',
#   'administered_dose1_recip_12pluspop_pct': '69.8',
#   'administered_dose1_recip_18plus': '6856',
#   'administered_dose1_recip_18pluspop_pct': '72.5',
#   'administered_dose1_recip_65plus': '2406',
#   'administered_dose1_recip_65pluspop_pct': '92.7',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '4',
#   'series_complete_12pluspop_pct_svi': '4',
#   'series_complete_18pluspop_pct_svi': '4',
#   'series_complete_65pluspop_pct_svi': '4',
#   'metro_status': 'Metro',
#   'series_complete_pop_pct_ur_equity': '4',
#   'series_complete_12pluspop_pct_ur_equity': '4',
#   'series_complete_18pluspop_pct_ur_equity': '4',
#   'series_complete_65pluspop_pct_ur_equity': '4'},
#  {'date': '2021-10-20T00:00:00.000',
#   'fips': '30103',
#   'mmwr_week': '42',
#   'recip_county': 'Treasure County',
#   'recip_state': 'MT',
#   'series_complete_pop_pct': '41.8',
#   'series_complete_yes': '291',
#   'series_complete_12plus': '291',
#   'series_complete_12pluspop': '49.8',
#   'series_complete_18plus': '290',
#   'series_complete_18pluspop': '52.8',
#   'series_complete_65plus': '166',
#   'series_complete_65pluspop': '82.6',
#   'completeness_pct': '95.7',
#   'administered_dose1_recip': '327',
#   'administered_dose1_pop_pct': '47',
#   'administered_dose1_recip_12plus': '327',
#   'administered_dose1_recip_12pluspop_pct': '56.0',
#   'administered_dose1_recip_18plus': '324',
#   'administered_dose1_recip_18pluspop_pct': '59',
#   'administered_dose1_recip_65plus': '175',
#   'administered_dose1_recip_65pluspop_pct': '87.1',
#   'svi_ctgy': 'A',
#   'series_complete_pop_pct_svi': '3',
#   'series_complete_12pluspop_pct_svi': '3',
#   'series_complete_18pluspop_pct_svi': '4',
#   'series_complete_65pluspop_pct_svi': '4',
#   'metro_status': 'Non-metro',
#   'series_complete_pop_pct_ur_equity': '7',
#   'series_complete_12pluspop_pct_ur_equity': '7',
#   'series_complete_18pluspop_pct_ur_equity': '8',
#   'series_complete_65pluspop_pct_ur_equity': '8'}]

# %%
#CDC COVID-19 mortality rate in the US by age and sex url
mort_url = "https://data.cdc.gov/resource/9bhg-hcku"

# %%
#request API and get json objects
mort_response = requests.get(mort_url).json()
mort_response
# Out:
# [{'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': 'All Ages',
#   'covid_19_deaths': '723880',
#   'total_deaths': '5928410',
#   'pneumonia_deaths': '649389',
#   'pneumonia_and_covid_19_deaths': '369136',
#   'influenza_deaths': '9372',
#   'pneumonia_influenza_or_covid': '1012160'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': 'Under 1 year',
#   'covid_19_deaths': '132',
#   'total_deaths': '33432',
#   'pneumonia_deaths': '367',
#   'pneumonia_and_covid_19_deaths': '16',
#   'influenza_deaths': '23',
#   'pneumonia_influenza_or_covid': '506'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '0-17 years',
#   'covid_19_deaths': '542',
#   'total_deaths': '59268',
#   'pneumonia_deaths': '1043',
#   'pneumonia_and_covid_19_deaths': '138',
#   'influenza_deaths': '189',
#   'pneumonia_influenza_or_covid': '1636'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '1-4 years',
#   'covid_19_deaths': '63',
#   'total_deaths': '6236',
#   'pneumonia_deaths': '210',
#   'pneumonia_and_covid_19_deaths': '16',
#   'influenza_deaths': '65',
#   'pneumonia_influenza_or_covid': '322'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '5-14 years',
#   'covid_19_deaths': '172',
#   'total_deaths': '9911',
#   'pneumonia_deaths': '303',
#   'pneumonia_and_covid_19_deaths': '54',
#   'influenza_deaths': '80',
#   'pneumonia_influenza_or_covid': '501'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '15-24 years',
#   'covid_19_deaths': '1665',
#   'total_deaths': '63951',
#   'pneumonia_deaths': '1591',
#   'pneumonia_and_covid_19_deaths': '713',
#   'influenza_deaths': '80',
#   'pneumonia_influenza_or_covid': '2618'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '18-29 years',
#   'covid_19_deaths': '4014',
#   'total_deaths': '112869',
#   'pneumonia_deaths': '3701',
#   'pneumonia_and_covid_19_deaths': '1897',
#   'influenza_deaths': '149',
#   'pneumonia_influenza_or_covid': '5955'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '25-34 years',
#   'covid_19_deaths': '7216',
#   'total_deaths': '133574',
#   'pneumonia_deaths': '6290',
#   'pneumonia_and_covid_19_deaths': '3627',
#   'influenza_deaths': '237',
#   'pneumonia_influenza_or_covid': '10098'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '30-39 years',
#   'covid_19_deaths': '11749',
#   'total_deaths': '163896',
#   'pneumonia_deaths': '9917',
#   'pneumonia_and_covid_19_deaths': '6040',
#   'influenza_deaths': '324',
#   'pneumonia_influenza_or_covid': '15925'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '35-44 years',
#   'covid_19_deaths': '18228',
#   'total_deaths': '194759',
#   'pneumonia_deaths': '15069',
#   'pneumonia_and_covid_19_deaths': '9522',
#   'influenza_deaths': '370',
#   'pneumonia_influenza_or_covid': '24104'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '40-49 years',
#   'covid_19_deaths': '29045',
#   'total_deaths': '244924',
#   'pneumonia_deaths': '23417',
#   'pneumonia_and_covid_19_deaths': '15471',
#   'influenza_deaths': '509',
#   'pneumonia_influenza_or_covid': '37427'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '45-54 years',
#   'covid_19_deaths': '45323',
#   'total_deaths': '348554',
#   'pneumonia_deaths': '37505',
#   'pneumonia_and_covid_19_deaths': '24747',
#   'influenza_deaths': '807',
#   'pneumonia_influenza_or_covid': '58761'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '50-64 years',
#   'covid_19_deaths': '128814',
#   'total_deaths': '999730',
#   'pneumonia_deaths': '115653',
#   'pneumonia_and_covid_19_deaths': '71495',
#   'influenza_deaths': '2230',
#   'pneumonia_influenza_or_covid': '174838'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '55-64 years',
#   'covid_19_deaths': '101365',
#   'total_deaths': '790270',
#   'pneumonia_deaths': '92396',
#   'pneumonia_and_covid_19_deaths': '56346',
#   'influenza_deaths': '1739',
#   'pneumonia_influenza_or_covid': '138871'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '65-74 years',
#   'covid_19_deaths': '163293',
#   'total_deaths': '1205591',
#   'pneumonia_deaths': '152654',
#   'pneumonia_and_covid_19_deaths': '90529',
#   'influenza_deaths': '2037',
#   'pneumonia_influenza_or_covid': '227115'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '75-84 years',
#   'covid_19_deaths': '189790',
#   'total_deaths': '1432156',
#   'pneumonia_deaths': '175449',
#   'pneumonia_and_covid_19_deaths': '99219',
#   'influenza_deaths': '2028',
#   'pneumonia_influenza_or_covid': '267762'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'All Sexes',
#   'age_group': '85 years and over',
#   'covid_19_deaths': '196633',
#   'total_deaths': '1709976',
#   'pneumonia_deaths': '167555',
#   'pneumonia_and_covid_19_deaths': '84347',
#   'influenza_deaths': '1906',
#   'pneumonia_influenza_or_covid': '281502'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': 'All Ages',
#   'covid_19_deaths': '398938',
#   'total_deaths': '3120675',
#   'pneumonia_deaths': '363793',
#   'pneumonia_and_covid_19_deaths': '212539',
#   'influenza_deaths': '4854',
#   'pneumonia_influenza_or_covid': '554227'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': 'Under 1 year',
#   'covid_19_deaths': '70',
#   'total_deaths': '18390',
#   'pneumonia_deaths': '214',
#   'pneumonia_and_covid_19_deaths': '12',
#   'influenza_deaths': '11',
#   'pneumonia_influenza_or_covid': '283'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '0-17 years',
#   'covid_19_deaths': '294',
#   'total_deaths': '34655',
#   'pneumonia_deaths': '569',
#   'pneumonia_and_covid_19_deaths': '77',
#   'influenza_deaths': '104',
#   'pneumonia_influenza_or_covid': '890'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '1-4 years',
#   'covid_19_deaths': '30',
#   'total_deaths': '3526',
#   'pneumonia_deaths': '100',
#   'pneumonia_and_covid_19_deaths': '6',
#   'influenza_deaths': '41',
#   'pneumonia_influenza_or_covid': '165'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '5-14 years',
#   'covid_19_deaths': '95',
#   'total_deaths': '5860',
#   'pneumonia_deaths': '160',
#   'pneumonia_and_covid_19_deaths': '32',
#   'influenza_deaths': '40',
#   'pneumonia_influenza_or_covid': '263'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '15-24 years',
#   'covid_19_deaths': '986',
#   'total_deaths': '47025',
#   'pneumonia_deaths': '960',
#   'pneumonia_and_covid_19_deaths': '416',
#   'influenza_deaths': '38',
#   'pneumonia_influenza_or_covid': '1564'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '18-29 years',
#   'covid_19_deaths': '2460',
#   'total_deaths': '82509',
#   'pneumonia_deaths': '2252',
#   'pneumonia_and_covid_19_deaths': '1134',
#   'influenza_deaths': '79',
#   'pneumonia_influenza_or_covid': '3648'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '25-34 years',
#   'covid_19_deaths': '4450',
#   'total_deaths': '94239',
#   'pneumonia_deaths': '3823',
#   'pneumonia_and_covid_19_deaths': '2229',
#   'influenza_deaths': '118',
#   'pneumonia_influenza_or_covid': '6150'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '30-39 years',
#   'covid_19_deaths': '7365',
#   'total_deaths': '111103',
#   'pneumonia_deaths': '6082',
#   'pneumonia_and_covid_19_deaths': '3805',
#   'influenza_deaths': '159',
#   'pneumonia_influenza_or_covid': '9785'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '35-44 years',
#   'covid_19_deaths': '11525',
#   'total_deaths': '127524',
#   'pneumonia_deaths': '9263',
#   'pneumonia_and_covid_19_deaths': '6039',
#   'influenza_deaths': '195',
#   'pneumonia_influenza_or_covid': '14914'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '40-49 years',
#   'covid_19_deaths': '18604',
#   'total_deaths': '155992',
#   'pneumonia_deaths': '14458',
#   'pneumonia_and_covid_19_deaths': '9935',
#   'influenza_deaths': '285',
#   'pneumonia_influenza_or_covid': '23359'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '45-54 years',
#   'covid_19_deaths': '29495',
#   'total_deaths': '219155',
#   'pneumonia_deaths': '23328',
#   'pneumonia_and_covid_19_deaths': '16088',
#   'influenza_deaths': '472',
#   'pneumonia_influenza_or_covid': '37119'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '50-64 years',
#   'covid_19_deaths': '81093',
#   'total_deaths': '617200',
#   'pneumonia_deaths': '70179',
#   'pneumonia_and_covid_19_deaths': '44527',
#   'influenza_deaths': '1288',
#   'pneumonia_influenza_or_covid': '107786'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '55-64 years',
#   'covid_19_deaths': '63165',
#   'total_deaths': '485740',
#   'pneumonia_deaths': '55692',
#   'pneumonia_and_covid_19_deaths': '34656',
#   'influenza_deaths': '1000',
#   'pneumonia_influenza_or_covid': '85010'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '65-74 years',
#   'covid_19_deaths': '98108',
#   'total_deaths': '699866',
#   'pneumonia_deaths': '91230',
#   'pneumonia_and_covid_19_deaths': '54807',
#   'influenza_deaths': '1148',
#   'pneumonia_influenza_or_covid': '135454'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '75-84 years',
#   'covid_19_deaths': '106521',
#   'total_deaths': '747385',
#   'pneumonia_deaths': '100062',
#   'pneumonia_and_covid_19_deaths': '57607',
#   'influenza_deaths': '1017',
#   'pneumonia_influenza_or_covid': '149835'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Male',
#   'age_group': '85 years and over',
#   'covid_19_deaths': '84493',
#   'total_deaths': '671965',
#   'pneumonia_deaths': '78961',
#   'pneumonia_and_covid_19_deaths': '40647',
#   'influenza_deaths': '774',
#   'pneumonia_influenza_or_covid': '123470'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': 'All Ages',
#   'covid_19_deaths': '324942',
#   'total_deaths': '2807735',
#   'pneumonia_deaths': '285596',
#   'pneumonia_and_covid_19_deaths': '156597',
#   'influenza_deaths': '4518',
#   'pneumonia_influenza_or_covid': '457933'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': 'Under 1 year',
#   'covid_19_deaths': '62',
#   'total_deaths': '15042',
#   'pneumonia_deaths': '153',
#   'pneumonia_and_covid_19_deaths': '4',
#   'influenza_deaths': '12',
#   'pneumonia_influenza_or_covid': '223'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '0-17 years',
#   'covid_19_deaths': '248',
#   'total_deaths': '24613',
#   'pneumonia_deaths': '474',
#   'pneumonia_and_covid_19_deaths': '61',
#   'influenza_deaths': '85',
#   'pneumonia_influenza_or_covid': '746'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '1-4 years',
#   'covid_19_deaths': '33',
#   'total_deaths': '2710',
#   'pneumonia_deaths': '110',
#   'pneumonia_and_covid_19_deaths': '10',
#   'influenza_deaths': '24',
#   'pneumonia_influenza_or_covid': '157'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '5-14 years',
#   'covid_19_deaths': '77',
#   'total_deaths': '4051',
#   'pneumonia_deaths': '143',
#   'pneumonia_and_covid_19_deaths': '22',
#   'influenza_deaths': '40',
#   'pneumonia_influenza_or_covid': '238'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '15-24 years',
#   'covid_19_deaths': '679',
#   'total_deaths': '16926',
#   'pneumonia_deaths': '631',
#   'pneumonia_and_covid_19_deaths': '297',
#   'influenza_deaths': '42',
#   'pneumonia_influenza_or_covid': '1054'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '18-29 years',
#   'covid_19_deaths': '1554',
#   'total_deaths': '30360',
#   'pneumonia_deaths': '1449',
#   'pneumonia_and_covid_19_deaths': '763',
#   'influenza_deaths': '70',
#   'pneumonia_influenza_or_covid': '2307'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '25-34 years',
#   'covid_19_deaths': '2766',
#   'total_deaths': '39335',
#   'pneumonia_deaths': '2467',
#   'pneumonia_and_covid_19_deaths': '1398',
#   'influenza_deaths': '119',
#   'pneumonia_influenza_or_covid': '3948'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '30-39 years',
#   'covid_19_deaths': '4384',
#   'total_deaths': '52793',
#   'pneumonia_deaths': '3835',
#   'pneumonia_and_covid_19_deaths': '2235',
#   'influenza_deaths': '165',
#   'pneumonia_influenza_or_covid': '6140'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '35-44 years',
#   'covid_19_deaths': '6703',
#   'total_deaths': '67235',
#   'pneumonia_deaths': '5806',
#   'pneumonia_and_covid_19_deaths': '3483',
#   'influenza_deaths': '175',
#   'pneumonia_influenza_or_covid': '9190'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '40-49 years',
#   'covid_19_deaths': '10441',
#   'total_deaths': '88932',
#   'pneumonia_deaths': '8959',
#   'pneumonia_and_covid_19_deaths': '5536',
#   'influenza_deaths': '224',
#   'pneumonia_influenza_or_covid': '14068'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '45-54 years',
#   'covid_19_deaths': '15828',
#   'total_deaths': '129399',
#   'pneumonia_deaths': '14177',
#   'pneumonia_and_covid_19_deaths': '8659',
#   'influenza_deaths': '335',
#   'pneumonia_influenza_or_covid': '21642'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '50-64 years',
#   'covid_19_deaths': '47721',
#   'total_deaths': '382530',
#   'pneumonia_deaths': '45474',
#   'pneumonia_and_covid_19_deaths': '26968',
#   'influenza_deaths': '942',
#   'pneumonia_influenza_or_covid': '67052'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '55-64 years',
#   'covid_19_deaths': '38200',
#   'total_deaths': '304530',
#   'pneumonia_deaths': '36704',
#   'pneumonia_and_covid_19_deaths': '21690',
#   'influenza_deaths': '739',
#   'pneumonia_influenza_or_covid': '53861'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '65-74 years',
#   'covid_19_deaths': '65185',
#   'total_deaths': '505725',
#   'pneumonia_deaths': '61424',
#   'pneumonia_and_covid_19_deaths': '35722',
#   'influenza_deaths': '889',
#   'pneumonia_influenza_or_covid': '91661'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '75-84 years',
#   'covid_19_deaths': '83269',
#   'total_deaths': '684771',
#   'pneumonia_deaths': '75387',
#   'pneumonia_and_covid_19_deaths': '41612',
#   'influenza_deaths': '1011',
#   'pneumonia_influenza_or_covid': '117927'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'United States',
#   'sex': 'Female',
#   'age_group': '85 years and over',
#   'covid_19_deaths': '112140',
#   'total_deaths': '1038011',
#   'pneumonia_deaths': '88594',
#   'pneumonia_and_covid_19_deaths': '43700',
#   'influenza_deaths': '1132',
#   'pneumonia_influenza_or_covid': '158032'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': 'All Ages',
#   'covid_19_deaths': '14889',
#   'total_deaths': '114315',
#   'pneumonia_deaths': '10277',
#   'pneumonia_and_covid_19_deaths': '5214',
#   'influenza_deaths': '164',
#   'pneumonia_influenza_or_covid': '20094'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': 'Under 1 year',
#   'total_deaths': '707',
#   'pneumonia_influenza_or_covid': '11',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '0-17 years',
#   'total_deaths': '1270',
#   'pneumonia_deaths': '17',
#   'pneumonia_influenza_or_covid': '25',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '1-4 years',
#   'total_deaths': '159',
#   'pneumonia_and_covid_19_deaths': '0',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '5-14 years',
#   'covid_19_deaths': '0',
#   'total_deaths': '195',
#   'pneumonia_and_covid_19_deaths': '0',
#   'influenza_deaths': '0',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '15-24 years',
#   'covid_19_deaths': '28',
#   'total_deaths': '1315',
#   'pneumonia_deaths': '27',
#   'pneumonia_influenza_or_covid': '51',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '18-29 years',
#   'covid_19_deaths': '97',
#   'total_deaths': '2197',
#   'pneumonia_deaths': '68',
#   'pneumonia_and_covid_19_deaths': '35',
#   'pneumonia_influenza_or_covid': '133',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '25-34 years',
#   'covid_19_deaths': '186',
#   'total_deaths': '2537',
#   'pneumonia_deaths': '129',
#   'pneumonia_and_covid_19_deaths': '76',
#   'pneumonia_influenza_or_covid': '243',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '30-39 years',
#   'covid_19_deaths': '290',
#   'total_deaths': '3219',
#   'pneumonia_deaths': '200',
#   'pneumonia_and_covid_19_deaths': '106',
#   'pneumonia_influenza_or_covid': '389',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '35-44 years',
#   'covid_19_deaths': '490',
#   'total_deaths': '4134',
#   'pneumonia_deaths': '289',
#   'pneumonia_and_covid_19_deaths': '172',
#   'pneumonia_influenza_or_covid': '613',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '40-49 years',
#   'covid_19_deaths': '752',
#   'total_deaths': '5485',
#   'pneumonia_deaths': '440',
#   'pneumonia_and_covid_19_deaths': '263',
#   'pneumonia_influenza_or_covid': '935',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '45-54 years',
#   'covid_19_deaths': '1150',
#   'total_deaths': '7715',
#   'pneumonia_deaths': '662',
#   'pneumonia_and_covid_19_deaths': '395',
#   'influenza_deaths': '16',
#   'pneumonia_influenza_or_covid': '1432'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '50-64 years',
#   'covid_19_deaths': '3167',
#   'total_deaths': '21930',
#   'pneumonia_deaths': '2081',
#   'pneumonia_and_covid_19_deaths': '1132',
#   'influenza_deaths': '58',
#   'pneumonia_influenza_or_covid': '4168'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '55-64 years',
#   'covid_19_deaths': '2455',
#   'total_deaths': '17339',
#   'pneumonia_deaths': '1683',
#   'pneumonia_and_covid_19_deaths': '887',
#   'influenza_deaths': '45',
#   'pneumonia_influenza_or_covid': '3291'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '65-74 years',
#   'covid_19_deaths': '3837',
#   'total_deaths': '25620',
#   'pneumonia_deaths': '2695',
#   'pneumonia_and_covid_19_deaths': '1380',
#   'influenza_deaths': '44',
#   'pneumonia_influenza_or_covid': '5193'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '75-84 years',
#   'covid_19_deaths': '3867',
#   'total_deaths': '28477',
#   'pneumonia_deaths': '2786',
#   'pneumonia_and_covid_19_deaths': '1395',
#   'influenza_deaths': '27',
#   'pneumonia_influenza_or_covid': '5280'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'All Sexes',
#   'age_group': '85 years and over',
#   'covid_19_deaths': '2872',
#   'total_deaths': '26117',
#   'pneumonia_deaths': '1990',
#   'pneumonia_and_covid_19_deaths': '901',
#   'influenza_deaths': '15',
#   'pneumonia_influenza_or_covid': '3971'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': 'All Ages',
#   'covid_19_deaths': '7962',
#   'total_deaths': '59782',
#   'pneumonia_deaths': '5575',
#   'pneumonia_and_covid_19_deaths': '2820',
#   'influenza_deaths': '97',
#   'pneumonia_influenza_or_covid': '10800'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': 'Under 1 year',
#   'total_deaths': '403',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '0-17 years',
#   'total_deaths': '786',
#   'pneumonia_influenza_or_covid': '12',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '1-4 years',
#   'covid_19_deaths': '0',
#   'total_deaths': '92',
#   'pneumonia_deaths': '0',
#   'pneumonia_and_covid_19_deaths': '0',
#   'influenza_deaths': '0',
#   'pneumonia_influenza_or_covid': '0'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '5-14 years',
#   'covid_19_deaths': '0',
#   'total_deaths': '129',
#   'pneumonia_and_covid_19_deaths': '0',
#   'influenza_deaths': '0',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '15-24 years',
#   'covid_19_deaths': '15',
#   'total_deaths': '969',
#   'pneumonia_deaths': '13',
#   'pneumonia_influenza_or_covid': '26',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '18-29 years',
#   'covid_19_deaths': '57',
#   'total_deaths': '1593',
#   'pneumonia_deaths': '37',
#   'pneumonia_and_covid_19_deaths': '20',
#   'pneumonia_influenza_or_covid': '77',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '25-34 years',
#   'covid_19_deaths': '108',
#   'total_deaths': '1725',
#   'pneumonia_deaths': '77',
#   'pneumonia_and_covid_19_deaths': '46',
#   'pneumonia_influenza_or_covid': '141',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '30-39 years',
#   'covid_19_deaths': '171',
#   'total_deaths': '2081',
#   'pneumonia_deaths': '117',
#   'pneumonia_and_covid_19_deaths': '64',
#   'pneumonia_influenza_or_covid': '226',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '35-44 years',
#   'covid_19_deaths': '274',
#   'total_deaths': '2604',
#   'pneumonia_deaths': '166',
#   'pneumonia_and_covid_19_deaths': '96',
#   'pneumonia_influenza_or_covid': '347',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '40-49 years',
#   'covid_19_deaths': '418',
#   'total_deaths': '3363',
#   'pneumonia_deaths': '261',
#   'pneumonia_and_covid_19_deaths': '154',
#   'pneumonia_influenza_or_covid': '528',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '45-54 years',
#   'covid_19_deaths': '660',
#   'total_deaths': '4661',
#   'pneumonia_deaths': '394',
#   'pneumonia_and_covid_19_deaths': '236',
#   'pneumonia_influenza_or_covid': '826',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '50-64 years',
#   'covid_19_deaths': '1800',
#   'total_deaths': '13151',
#   'pneumonia_deaths': '1163',
#   'pneumonia_and_covid_19_deaths': '622',
#   'influenza_deaths': '37',
#   'pneumonia_influenza_or_covid': '2373'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '55-64 years',
#   'covid_19_deaths': '1391',
#   'total_deaths': '10391',
#   'pneumonia_deaths': '929',
#   'pneumonia_and_covid_19_deaths': '478',
#   'influenza_deaths': '30',
#   'pneumonia_influenza_or_covid': '1868'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '65-74 years',
#   'covid_19_deaths': '2193',
#   'total_deaths': '14696',
#   'pneumonia_deaths': '1575',
#   'pneumonia_and_covid_19_deaths': '795',
#   'influenza_deaths': '27',
#   'pneumonia_influenza_or_covid': '2998'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '75-84 years',
#   'covid_19_deaths': '2114',
#   'total_deaths': '14425',
#   'pneumonia_deaths': '1511',
#   'pneumonia_and_covid_19_deaths': '757',
#   'influenza_deaths': '13',
#   'pneumonia_influenza_or_covid': '2878'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Male',
#   'age_group': '85 years and over',
#   'covid_19_deaths': '1205',
#   'total_deaths': '9687',
#   'pneumonia_deaths': '904',
#   'pneumonia_and_covid_19_deaths': '407',
#   'pneumonia_influenza_or_covid': '1708',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': 'All Ages',
#   'covid_19_deaths': '6927',
#   'total_deaths': '54533',
#   'pneumonia_deaths': '4702',
#   'pneumonia_and_covid_19_deaths': '2394',
#   'influenza_deaths': '67',
#   'pneumonia_influenza_or_covid': '9294'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': 'Under 1 year',
#   'total_deaths': '304',
#   'influenza_deaths': '0',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '0-17 years',
#   'total_deaths': '484',
#   'pneumonia_deaths': '10',
#   'pneumonia_influenza_or_covid': '13',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '1-4 years',
#   'total_deaths': '67',
#   'pneumonia_and_covid_19_deaths': '0',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '5-14 years',
#   'covid_19_deaths': '0',
#   'total_deaths': '66',
#   'pneumonia_and_covid_19_deaths': '0',
#   'influenza_deaths': '0',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '15-24 years',
#   'covid_19_deaths': '13',
#   'total_deaths': '346',
#   'pneumonia_deaths': '14',
#   'influenza_deaths': '0',
#   'pneumonia_influenza_or_covid': '25',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '18-29 years',
#   'covid_19_deaths': '40',
#   'total_deaths': '604',
#   'pneumonia_deaths': '31',
#   'pneumonia_and_covid_19_deaths': '15',
#   'influenza_deaths': '0',
#   'pneumonia_influenza_or_covid': '56'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '25-34 years',
#   'covid_19_deaths': '78',
#   'total_deaths': '812',
#   'pneumonia_deaths': '52',
#   'pneumonia_and_covid_19_deaths': '30',
#   'pneumonia_influenza_or_covid': '102',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '30-39 years',
#   'covid_19_deaths': '119',
#   'total_deaths': '1138',
#   'pneumonia_deaths': '83',
#   'pneumonia_and_covid_19_deaths': '42',
#   'pneumonia_influenza_or_covid': '163',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '35-44 years',
#   'covid_19_deaths': '216',
#   'total_deaths': '1530',
#   'pneumonia_deaths': '123',
#   'pneumonia_and_covid_19_deaths': '76',
#   'pneumonia_influenza_or_covid': '266',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '40-49 years',
#   'covid_19_deaths': '334',
#   'total_deaths': '2122',
#   'pneumonia_deaths': '179',
#   'pneumonia_and_covid_19_deaths': '109',
#   'pneumonia_influenza_or_covid': '407',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '45-54 years',
#   'covid_19_deaths': '490',
#   'total_deaths': '3054',
#   'pneumonia_deaths': '268',
#   'pneumonia_and_covid_19_deaths': '159',
#   'pneumonia_influenza_or_covid': '606',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '50-64 years',
#   'covid_19_deaths': '1367',
#   'total_deaths': '8779',
#   'pneumonia_deaths': '918',
#   'pneumonia_and_covid_19_deaths': '510',
#   'influenza_deaths': '21',
#   'pneumonia_influenza_or_covid': '1795'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '55-64 years',
#   'covid_19_deaths': '1064',
#   'total_deaths': '6948',
#   'pneumonia_deaths': '754',
#   'pneumonia_and_covid_19_deaths': '409',
#   'influenza_deaths': '15',
#   'pneumonia_influenza_or_covid': '1423'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '65-74 years',
#   'covid_19_deaths': '1644',
#   'total_deaths': '10924',
#   'pneumonia_deaths': '1120',
#   'pneumonia_and_covid_19_deaths': '585',
#   'influenza_deaths': '17',
#   'pneumonia_influenza_or_covid': '2195'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '75-84 years',
#   'covid_19_deaths': '1753',
#   'total_deaths': '14052',
#   'pneumonia_deaths': '1275',
#   'pneumonia_and_covid_19_deaths': '638',
#   'influenza_deaths': '14',
#   'pneumonia_influenza_or_covid': '2402'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alabama',
#   'sex': 'Female',
#   'age_group': '85 years and over',
#   'covid_19_deaths': '1667',
#   'total_deaths': '16430',
#   'pneumonia_deaths': '1086',
#   'pneumonia_and_covid_19_deaths': '494',
#   'pneumonia_influenza_or_covid': '2263',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alaska',
#   'sex': 'All Sexes',
#   'age_group': 'All Ages',
#   'covid_19_deaths': '633',
#   'total_deaths': '8706',
#   'pneumonia_deaths': '637',
#   'pneumonia_and_covid_19_deaths': '374',
#   'influenza_deaths': '10',
#   'pneumonia_influenza_or_covid': '906'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alaska',
#   'sex': 'All Sexes',
#   'age_group': 'Under 1 year',
#   'total_deaths': '82',
#   'pneumonia_and_covid_19_deaths': '0',
#   'influenza_deaths': '0',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alaska',
#   'sex': 'All Sexes',
#   'age_group': '0-17 years',
#   'total_deaths': '171',
#   'pneumonia_and_covid_19_deaths': '0',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alaska',
#   'sex': 'All Sexes',
#   'age_group': '1-4 years',
#   'covid_19_deaths': '0',
#   'total_deaths': '11',
#   'pneumonia_and_covid_19_deaths': '0',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Alaska',
#   'sex': 'All Sexes',
#   'age_group': '5-14 years',
#   'covid_19_deaths': '0',
#   'total_deaths': '40',
#   'pneumonia_deaths': '0',
#   'pneumonia_and_covid_19_deaths': '0',
#   'influenza_deaths': '0',
#   'pneumonia_influenza_or_covid': '0'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
# ...
#   'pneumonia_and_covid_19_deaths': '348',
#   'influenza_deaths': '17',
#   'pneumonia_influenza_or_covid': '1009'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Kentucky',
#   'sex': 'Female',
#   'age_group': '65-74 years',
#   'covid_19_deaths': '1029',
#   'total_deaths': '9493',
#   'pneumonia_deaths': '1268',
#   'pneumonia_and_covid_19_deaths': '601',
#   'influenza_deaths': '20',
#   'pneumonia_influenza_or_covid': '1715'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Kentucky',
#   'sex': 'Female',
#   'age_group': '75-84 years',
#   'covid_19_deaths': '1361',
#   'total_deaths': '11862',
#   'pneumonia_deaths': '1517',
#   'pneumonia_and_covid_19_deaths': '707',
#   'influenza_deaths': '16',
#   'pneumonia_influenza_or_covid': '2186'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Kentucky',
#   'sex': 'Female',
#   'age_group': '85 years and over',
#   'covid_19_deaths': '1655',
#   'total_deaths': '14196',
#   'pneumonia_deaths': '1401',
#   'pneumonia_and_covid_19_deaths': '592',
#   'influenza_deaths': '16',
#   'pneumonia_influenza_or_covid': '2480'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': 'All Ages',
#   'covid_19_deaths': '12738',
#   'total_deaths': '98205',
#   'pneumonia_deaths': '10189',
#   'pneumonia_and_covid_19_deaths': '6669',
#   'influenza_deaths': '107',
#   'pneumonia_influenza_or_covid': '16353'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': 'Under 1 year',
#   'total_deaths': '651',
#   'pneumonia_deaths': '11',
#   'pneumonia_and_covid_19_deaths': '0',
#   'pneumonia_influenza_or_covid': '16',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '0-17 years',
#   'covid_19_deaths': '13',
#   'total_deaths': '1224',
#   'pneumonia_deaths': '29',
#   'pneumonia_influenza_or_covid': '41',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '1-4 years',
#   'total_deaths': '147',
#   'influenza_deaths': '0',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '5-14 years',
#   'total_deaths': '205',
#   'pneumonia_and_covid_19_deaths': '0',
#   'pneumonia_influenza_or_covid': '11',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '15-24 years',
#   'covid_19_deaths': '49',
#   'total_deaths': '1349',
#   'pneumonia_deaths': '35',
#   'pneumonia_and_covid_19_deaths': '23',
#   'pneumonia_influenza_or_covid': '62',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '18-29 years',
#   'covid_19_deaths': '88',
#   'total_deaths': '2272',
#   'pneumonia_deaths': '78',
#   'pneumonia_and_covid_19_deaths': '44',
#   'pneumonia_influenza_or_covid': '123',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '25-34 years',
#   'covid_19_deaths': '148',
#   'total_deaths': '2698',
#   'pneumonia_deaths': '123',
#   'pneumonia_and_covid_19_deaths': '74',
#   'pneumonia_influenza_or_covid': '199',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '30-39 years',
#   'covid_19_deaths': '258',
#   'total_deaths': '3388',
#   'pneumonia_deaths': '193',
#   'pneumonia_and_covid_19_deaths': '139',
#   'pneumonia_influenza_or_covid': '319',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '35-44 years',
#   'covid_19_deaths': '386',
#   'total_deaths': '3986',
#   'pneumonia_deaths': '288',
#   'pneumonia_and_covid_19_deaths': '209',
#   'pneumonia_influenza_or_covid': '470',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '40-49 years',
#   'covid_19_deaths': '597',
#   'total_deaths': '4860',
#   'pneumonia_deaths': '401',
#   'pneumonia_and_covid_19_deaths': '300',
#   'pneumonia_influenza_or_covid': '703',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '45-54 years',
#   'covid_19_deaths': '928',
#   'total_deaths': '6620',
#   'pneumonia_deaths': '645',
#   'pneumonia_and_covid_19_deaths': '487',
#   'influenza_deaths': '15',
#   'pneumonia_influenza_or_covid': '1100'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '50-64 years',
#   'covid_19_deaths': '2662',
#   'total_deaths': '19053',
#   'pneumonia_deaths': '2075',
#   'pneumonia_and_covid_19_deaths': '1450',
#   'influenza_deaths': '31',
#   'pneumonia_influenza_or_covid': '3310'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '55-64 years',
#   'covid_19_deaths': '2098',
#   'total_deaths': '15141',
#   'pneumonia_deaths': '1660',
#   'pneumonia_and_covid_19_deaths': '1142',
#   'influenza_deaths': '21',
#   'pneumonia_influenza_or_covid': '2630'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '65-74 years',
#   'covid_19_deaths': '3237',
#   'total_deaths': '21757',
#   'pneumonia_deaths': '2648',
#   'pneumonia_and_covid_19_deaths': '1775',
#   'influenza_deaths': '21',
#   'pneumonia_influenza_or_covid': '4128'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '75-84 years',
#   'covid_19_deaths': '3336',
#   'total_deaths': '23081',
#   'pneumonia_deaths': '2672',
#   'pneumonia_and_covid_19_deaths': '1743',
#   'influenza_deaths': '23',
#   'pneumonia_influenza_or_covid': '4287'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'All Sexes',
#   'age_group': '85 years and over',
#   'covid_19_deaths': '2547',
#   'total_deaths': '22570',
#   'pneumonia_deaths': '2093',
#   'pneumonia_and_covid_19_deaths': '1215',
#   'influenza_deaths': '17',
#   'pneumonia_influenza_or_covid': '3442'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'Male',
#   'age_group': 'All Ages',
#   'covid_19_deaths': '6946',
#   'total_deaths': '52322',
#   'pneumonia_deaths': '5577',
#   'pneumonia_and_covid_19_deaths': '3700',
#   'influenza_deaths': '49',
#   'pneumonia_influenza_or_covid': '8864'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'Male',
#   'age_group': 'Under 1 year',
#   'total_deaths': '353',
#   'pneumonia_and_covid_19_deaths': '0',
#   'influenza_deaths': '0',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'Male',
#   'age_group': '0-17 years',
#   'total_deaths': '718',
#   'pneumonia_deaths': '14',
#   'influenza_deaths': '0',
#   'pneumonia_influenza_or_covid': '20',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'Male',
#   'age_group': '1-4 years',
#   'total_deaths': '79',
#   'pneumonia_and_covid_19_deaths': '0',
#   'influenza_deaths': '0',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'Male',
#   'age_group': '5-14 years',
#   'total_deaths': '125',
#   'pneumonia_and_covid_19_deaths': '0',
#   'influenza_deaths': '0',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'Male',
#   'age_group': '15-24 years',
#   'covid_19_deaths': '28',
#   'total_deaths': '977',
#   'pneumonia_deaths': '18',
#   'pneumonia_and_covid_19_deaths': '11',
#   'influenza_deaths': '0',
#   'pneumonia_influenza_or_covid': '35'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'Male',
#   'age_group': '18-29 years',
#   'covid_19_deaths': '49',
#   'total_deaths': '1639',
#   'pneumonia_deaths': '41',
#   'pneumonia_and_covid_19_deaths': '23',
#   'influenza_deaths': '0',
#   'pneumonia_influenza_or_covid': '67'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'Male',
#   'age_group': '25-34 years',
#   'covid_19_deaths': '80',
#   'total_deaths': '1843',
#   'pneumonia_deaths': '61',
#   'pneumonia_and_covid_19_deaths': '36',
#   'pneumonia_influenza_or_covid': '106',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'Male',
#   'age_group': '30-39 years',
#   'covid_19_deaths': '141',
#   'total_deaths': '2233',
#   'pneumonia_deaths': '99',
#   'pneumonia_and_covid_19_deaths': '66',
#   'pneumonia_influenza_or_covid': '177',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'Male',
#   'age_group': '35-44 years',
#   'covid_19_deaths': '218',
#   'total_deaths': '2598',
#   'pneumonia_deaths': '160',
#   'pneumonia_and_covid_19_deaths': '114',
#   'pneumonia_influenza_or_covid': '266',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'Male',
#   'age_group': '40-49 years',
#   'covid_19_deaths': '349',
#   'total_deaths': '3087',
#   'pneumonia_deaths': '231',
#   'pneumonia_and_covid_19_deaths': '177',
#   'pneumonia_influenza_or_covid': '405',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'Male',
#   'age_group': '45-54 years',
#   'covid_19_deaths': '558',
#   'total_deaths': '4134',
#   'pneumonia_deaths': '369',
#   'pneumonia_and_covid_19_deaths': '291',
#   'pneumonia_influenza_or_covid': '641',
#   'footnote': 'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'Male',
#   'age_group': '50-64 years',
#   'covid_19_deaths': '1571',
#   'total_deaths': '11637',
#   'pneumonia_deaths': '1209',
#   'pneumonia_and_covid_19_deaths': '849',
#   'influenza_deaths': '16',
#   'pneumonia_influenza_or_covid': '1942'},
#  {'data_as_of': '2021-10-20T00:00:00.000',
#   'start_date': '2020-01-01T00:00:00.000',
#   'end_date': '2021-10-16T00:00:00.000',
#   'group': 'By Total',
#   'state': 'Louisiana',
#   'sex': 'Male',
#   'age_group': '55-64 years',
#   'covid_19_deaths': '1229',
#   'total_deaths': '9205',
#   'pneumonia_deaths': '973',
#   'pneumonia_and_covid_19_deaths': '664',
#   'influenza_deaths': '13',
#   'pneumonia_influenza_or_covid': '1546'}]

# %%
def daterange(date1, date2):
    for n in range(int ((date2 - date1).days)+1):
        yield date1 + timedelta(n)

start_dt = date(2015, 12, 20)
end_dt = date(2016, 1, 11)
for dt in daterange(start_dt, end_dt):
    print(dt.strftime("%Y-%m-%d"))
# Out:
# 2015-12-20
# 2015-12-21
# 2015-12-22
# 2015-12-23
# 2015-12-24
# 2015-12-25
# 2015-12-26
# 2015-12-27
# 2015-12-28
# 2015-12-29
# 2015-12-30
# 2015-12-31
# 2016-01-01
# 2016-01-02
# 2016-01-03
# 2016-01-04
# 2016-01-05
# 2016-01-06
# 2016-01-07
# 2016-01-08
# 2016-01-09
# 2016-01-10
# 2016-01-11
